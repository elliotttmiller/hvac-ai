# %% [markdown]
# # 🟣 HVAC-Specific SAM Fine-Tuning Pipeline (v2 - Advanced)
# ## 🔧 Enhanced with Multi-Prompt Training & Resumability
#
# This notebook has been upgraded to include advanced features for creating a more robust and flexible model, inspired by recent research (e.g., SAM-PAR).

# %% [markdown]
# ### Phase 1: Initial Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install required dependencies
# !pip install torch torchvision --quiet
# !pip install opencv-python pycocotools matplotlib onnxruntime onnx --quiet
# !pip install git+https://github.com/facebookresearch/segment-anything.git --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 135.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 132.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for segment_anything (setup.py) ... done

# %%
import os
import zipfile
import json
import numpy as np
import matplotlib.pyplot as plt
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from pathlib import Path
from typing import Dict, List, Tuple, Optional, Any
from tqdm import tqdm
from statistics import mean
from pycocotools.coco import COCO
from pycocotools import mask as mask_utils
import random

# SAM imports
from segment_anything import sam_model_registry, SamPredictor
from segment_anything.utils.transforms import ResizeLongestSide

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %% [markdown]
# ### Phase 2: Configuration and Dataset Preparation

# %%
import torch
from pathlib import Path

CONFIG = {
    'device': 'cuda' if torch.cuda.is_available() else 'cpu',

    # --- STARTING MODEL ---
    # Path to the official pre-trained SAM weights. We start fresh for this new expert dataset.
    'model_path': '/content/sam_vit_h_4b8939.pth',

    # --- DATASET ---
    'dataset_zip_path': '/content/drive/MyDrive/hvac_dataset_coco.zip',
    'unzip_path': '/content/drive/MyDrive/hvac_dataset_coco',
    'annotations_file_name': '_annotations.coco.json',

    # --- OUTPUT & CHECKPOINTING ---
    'output_dir': '/content/drive/MyDrive/sam_finetuning_results',
    'best_model_save_path': '/content/drive/MyDrive/sam_finetuning_results/best_model_multiprompt_v1.pth',
    'latest_checkpoint_save_path': '/content/drive/MyDrive/sam_finetuning_results/latest_checkpoint_multiprompt_v1.pth',
    'resume_training': False, # SET TO TRUE TO RESUME FROM 'latest_checkpoint_save_path'

    # --- PROMPT ENGINEERING STRATEGY ---
    # Options: 'perfect_box', 'noisy_box', 'multi_prompt' (inspired by SAM-PAR paper)
    'prompt_strategy': 'multi_prompt',
    'bbox_noise_factor': 0.1, # How much to 'jiggle' the box in noisy_box or multi_prompt mode

    # --- MODEL & TRAINING HYPERPARAMETERS ---
    'model_type': 'vit_h',
    'image_size': 1024,
    'batch_size': 1,
    'num_workers': 0,
    'num_epochs': 1,
    'learning_rate': 1e-4,
    'weight_decay': 0,
    'early_stopping_patience': 10,
    'checkpoint_batch_interval': 300,
    'min_mask_area': 100,
}

Path(CONFIG['output_dir']).mkdir(parents=True, exist_ok=True)
print(f"✓ Configuration loaded. Using device: {CONFIG['device']}")
# Out:
# ✓ Configuration loaded. Using device: cuda

# %%
# Unzip the dataset if it hasn't been already
if not os.path.exists(CONFIG['unzip_path']):
    print(f"📁 Unzipping dataset from {CONFIG['dataset_zip_path']}...")
    with zipfile.ZipFile(CONFIG['dataset_zip_path'], 'r') as zip_ref:
        zip_ref.extractall(CONFIG['unzip_path'])
    print("✅ Unzipping complete.")
else:
    print("✅ Dataset already unzipped.")
# Out:
# 📁 Unzipping dataset from /content/drive/MyDrive/hvac_dataset_coco.zip...
# ✅ Unzipping complete.

# %% [markdown]
# ### Phase 3: Dataset Loading and DataLoader Creation

# %%
import os
import zipfile
import json
import numpy as np
import matplotlib.pyplot as plt
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from pathlib import Path
from typing import Dict, List, Tuple, Optional, Any
from tqdm import tqdm
from statistics import mean
from pycocotools.coco import COCO
from pycocotools import mask as mask_utils
import random

# SAM imports
from segment_anything import sam_model_registry, SamPredictor
from segment_anything.utils.transforms import ResizeLongestSide

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

def load_coco_split(dataset_root_path: str, split_name: str, annotations_file: str) -> Tuple[COCO, str]:
    split_path = os.path.join(dataset_root_path, split_name)
    annotations_path = os.path.join(split_path, annotations_file)
    if not os.path.exists(annotations_path):
        raise FileNotFoundError(f"Annotations file not found for '{split_name}' at: {annotations_path}")
    print(f"🔄 Loading '{split_name}' annotations from: {annotations_path}")
    coco = COCO(annotations_path)
    print(f"📊 Found {len(coco.getImgIds())} images in '{split_name}'.")
    return coco, split_path

def get_image_path(split_path: str, img_info: dict) -> str:
    full_path = os.path.join(split_path, img_info['file_name'])
    if not os.path.exists(full_path):
        raise FileNotFoundError(f"Image file not found: {img_info['file_name']} in {split_path}")
    return full_path

class HvacSamDataset(Dataset):
    def __init__(self, coco: COCO, image_ids: List[int], split_path: str, is_training: bool = True):
        self.coco = coco
        self.image_ids = image_ids
        self.split_path = split_path
        self.is_training = is_training
        self.resize_transform = ResizeLongestSide(CONFIG['image_size'])
        self.pixel_mean = torch.tensor([123.675, 116.28, 103.53]).view(-1, 1, 1)
        self.pixel_std = torch.tensor([58.395, 57.12, 57.375]).view(-1, 1, 1)
        self.prompt_strategy = CONFIG.get('prompt_strategy', 'perfect_box')

    def __len__(self) -> int:
        return len(self.image_ids)

    def _generate_prompt(self, mask: np.ndarray, bbox: List[float]):
        # For validation/testing, always use the perfect box for consistent evaluation
        if not self.is_training:
            return {'box': np.array(bbox)}

        # Determine the prompt type for this training item
        if self.prompt_strategy == 'multi_prompt':
            prompt_type = random.choice(['box', 'point', 'scribble'])
        elif self.prompt_strategy == 'point':
            prompt_type = 'point'
        elif self.prompt_strategy == 'noisy_box':
            prompt_type = 'box'
        else: # 'perfect_box'
            prompt_type = 'box'

        if prompt_type == 'box':
            noise_factor = CONFIG.get('bbox_noise_factor', 0) if self.prompt_strategy == 'noisy_box' or self.prompt_strategy == 'multi_prompt' else 0
            x, y, w, h = bbox
            x_noise = w * noise_factor * (random.random() - 0.5) * 2
            y_noise = h * noise_factor * (random.random() - 0.5) * 2
            w_noise = w * noise_factor * (random.random() - 0.5) * 2
            h_noise = h * noise_factor * (random.random() - 0.5) * 2
            box = np.array([x + x_noise, y + y_noise, w + w_noise, h + h_noise])
            return {'box': box}

        points = np.argwhere(mask)
        if len(points) == 0: return None

        if prompt_type == 'point':
            point = points[random.randint(0, len(points) - 1)]
            point_coords = np.array([[point[1], point[0]]]) # (x, y)
            point_labels = np.array([1])
            return {'point_coords': point_coords, 'point_labels': point_labels}

        elif prompt_type == 'scribble':
            num_points = min(5, len(points))
            point_indices = np.random.choice(len(points), num_points, replace=False)
            scribble_points = points[point_indices]
            point_coords = scribble_points[:, ::-1] # (row, col) -> (x, y)
            point_labels = np.ones(num_points)
            return {'point_coords': point_coords, 'point_labels': point_labels}

        return None

    def __getitem__(self, idx: int) -> Dict[str, Any]:
        img_id = self.image_ids[idx]
        img_info = self.coco.loadImgs([img_id])[0]
        image_path = get_image_path(self.split_path, img_info)
        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        ann_ids = self.coco.getAnnIds(imgIds=[img_id])
        annotations = self.coco.loadAnns(ann_ids)

        masks, prompts = [], []
        for ann in annotations:
            if 'segmentation' not in ann or ann.get('iscrowd', 0) == 1: continue
            mask = self.coco.annToMask(ann)
            if mask.sum() < CONFIG['min_mask_area']: continue

            prompt = self._generate_prompt(mask, ann['bbox'])
            if prompt:
                masks.append(mask.astype(bool))
                prompts.append(prompt)

        original_size = image.shape[:2]
        resized_image = self.resize_transform.apply_image(image)
        input_image_torch = torch.as_tensor(resized_image, dtype=torch.float32).permute(2, 0, 1).contiguous()
        input_image_torch = (input_image_torch - self.pixel_mean) / self.pixel_std
        h, w = input_image_torch.shape[-2:]
        padh, padw = CONFIG['image_size'] - h, CONFIG['image_size'] - w
        input_image_padded = torch.nn.functional.pad(input_image_torch, (0, padw, 0, padh))

        return {
            'image': input_image_padded,
            'masks': masks,
            'prompts': prompts,
            'original_size': original_size,
            'input_size': (h, w)
        }

def custom_collate_fn(batch: List[Dict]) -> Dict[str, Any]:
    return {
        'image': torch.stack([item['image'] for item in batch]),
        'masks': [item['masks'] for item in batch],
        'prompts': [item['prompts'] for item in batch],
        'original_size': [item['original_size'] for item in batch],
        'input_size': [item['input_size'] for item in batch]
    }

# Load datasets
train_coco, train_path = load_coco_split(CONFIG['unzip_path'], 'train', CONFIG['annotations_file_name'])
val_coco, val_path = load_coco_split(CONFIG['unzip_path'], 'valid', CONFIG['annotations_file_name'])
train_ids, val_ids = train_coco.getImgIds(), val_coco.getImgIds()

# Create Datasets and DataLoaders
train_dataset = HvacSamDataset(train_coco, train_ids, train_path, is_training=True)
val_dataset = HvacSamDataset(val_coco, val_ids, val_path, is_training=False)

train_loader = DataLoader(train_dataset, batch_size=CONFIG['batch_size'], shuffle=True, num_workers=CONFIG['num_workers'], collate_fn=custom_collate_fn)
val_loader = DataLoader(val_dataset, batch_size=CONFIG['batch_size'], shuffle=False, num_workers=CONFIG['num_workers'], collate_fn=custom_collate_fn)

print(f"\n✅ Training dataset initialized with {len(train_dataset)} samples.")
print(f"✅ Validation dataset initialized with {len(val_dataset)} samples.")

print(f"\nInspecting dataset directory: {CONFIG['unzip_path']}")
# !ls -R {CONFIG['unzip_path']}
# Out:
# 🔄 Loading 'train' annotations from: /content/drive/MyDrive/hvac_dataset_coco/train/_annotations.coco.json
# loading annotations into memory...
# Done (t=0.33s)
# creating index...
# index created!
# 📊 Found 2802 images in 'train'.
# 🔄 Loading 'valid' annotations from: /content/drive/MyDrive/hvac_dataset_coco/valid/_annotations.coco.json
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# 📊 Found 341 images in 'valid'.
#
# ✅ Training dataset initialized with 2802 samples.
# ✅ Validation dataset initialized with 341 samples.
#
# Inspecting dataset directory: /content/drive/MyDrive/hvac_dataset_coco
# /content/drive/MyDrive/hvac_dataset_coco:
# README.roboflow.txt  test  train  valid
#
# /content/drive/MyDrive/hvac_dataset_coco/test:
# 03-Mechanical_1_page_4_grid_1x3_jpg.rf.9b42123bb3bd2742a707dd110f23bee5.jpg
# 03-Mechanical_1_page_4_grid_3x2_jpg.rf.ba0723861f9acef4423783880408a711.jpg
# 03-Mechanical_1_page_5_grid_2x1_jpg.rf.4a0c650e0552d94979ca72ee07532051.jpg
# 0510162022_png.rf.1e00335da43b2f488279e5ee484ebb31.jpg
# 051032022_png.rf.da80432fd913fa151ddb42e90632b957.jpg
# 0510322022_png.rf.5a5197278ab7171280c376f4f711d5b5.jpg
# 0510342022_png.rf.0bcea2162d729f2a9b2acaf1e670555b.jpg
# 0510382022_png.rf.5d53bff0f16e271a106514d0d81ff79a.jpg
# 0510392022_png.rf.051e51fd4e059181cdb30575a1033696.jpg
# 07102022113_png.rf.a1622729364b15d3c28543610d4811db.jpg
# 111-5th-Ave-Winter-Organization-HVAC-Set_page_8_grid_2x1_jpg.rf.1967c050bbd00e596a50223d5f1c0682.jpg
# 1187-3rd-Warby-Parker-HVAC-Set_page_2_grid_2x1_jpg.rf.ac5a1f0dc2b44f48a95a37da61c26c18.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_4096_0_png.rf.f680585e9dd429e34a0fb1212ff089e1.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_0_1024_png.rf.b4a5f1d46148669245eab33365cceed6.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_2048_0_png.rf.37489e2e9fca49e4b09f1af569ad2c69.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_2048_1024_rot180_png.rf.ffbdc80e899c3ff85d20cbde23ce38e3.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_2048_2048_rot180_png.rf.72972355329b95ccee6211914f2e1559.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_3072_2048_png.rf.62887a0bdaea0ee4355eb57ca6948f52.jpg
# 1200246_P-ID_R1_31_12_2024_page_4_0_1024_png.rf.248f26ff5c4d727a2fd02f261e318c89.jpg
# 1200246_P-ID_R1_31_12_2024_page_4_1024_1024_rot180_png.rf.3444c6f3fe714ec6a4a2147a14d68455.jpg
# 1200246_P-ID_R1_31_12_2024_page_5_1024_0_png.rf.60e94778f82a5070bb2b6fb337c3e54e.jpg
# 1200246_P-ID_R1_31_12_2024_page_5_2048_1024_png.rf.a13306982bff27bc5a911a24d77db5c6.jpg
# 152-W-27th-St_21SW-Addendum-1-HVAC-Set_page_2_grid_2x1_jpg.rf.c6822d743c4d926e1358bcfddd82e6ce.jpg
# 1ROCK-STUDIO_ALL-TRADES_BidSet_2024030_page_51_grid_1x2_jpg.rf.b4e5bdef2485dfcacb39f2f507fa74de.jpg
# 200-Kent-Wonder-HVAC-Set_1_page_3_grid_1x3_jpg.rf.cc62835b5fce2ddf6d1be965b54269e2.jpg
# 200-Kent-Wonder-HVAC-Set_1_page_3_grid_2x2_jpg.rf.b462fb877623bfa0cde26453ba5c63b7.jpg
# 200-Madison-10th-Floor-HVAC-Set_1_page_4_grid_3x2_jpg.rf.86a59098273719cd1489086b538950a7.jpg
# 200-Madison-10th-Floor-HVAC-Set-Pre-Build_1_page_4_grid_1x1_jpg.rf.66680ebff3ceddd062b6470b5cf167e3.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_8_grid_1x3_jpg.rf.41bdd7a45672abb6294d2d227dcbb786.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_8_grid_2x2_jpg.rf.2d100d5e4950467937934d2a348d95be.jpg
# 2023_07_31-23_781-230818-m-for-building-Review-REV1_1_page_3_grid_2x2_jpg.rf.176477f35f420ea956efb47d0bdf1c36.jpg
# 2024_02_15_52-Mercer_Issued-for-50-CD-M-Series-_page_8_grid_9_jpg.rf.e7bdd427c5f9b18f54d36b1645d93655.jpg
# 2024_02_15_52-Mercer_Issued-for-50-CD-M-Series-_page_9_grid_18_jpg.rf.69319391bd645cbe6a56449708d33c5e.jpg
# 20240223_Tish_666-14FL-Issued-for-Bid_Full-Set_4_page_71_grid_19_jpg.rf.459bc574d800de50dc53f9fc17ee99ab.jpg
# 20240223_Tish_666-14FL-Issued-for-Bid_Full-Set_4_page_71_grid_24_jpg.rf.80d188409829560ccd8a9c0ce5fb1286.jpg
# 2200006_PID_R7_21_09_22_1200KLD_ALOK-INDUSTRIES-LTD-1-2-1-_page_1_0_1024_rot180_png.rf.03d0fc0ddd9b98dd40c76a73b237f3ff.jpg
# 2200006_PID_R7_21_09_22_1200KLD_ALOK-INDUSTRIES-LTD-1-2-1-_page_1_3072_0_png.rf.7b6633520671596e0b55cfd2da54da8c.jpg
# 2200006_PID_R7_21_09_22_1200KLD_ALOK-INDUSTRIES-LTD-1-2-1-_page_2_1024_1024_rot180_png.rf.904e1b973a7bb2626a7ec5ef3bf871a9.jpg
# 2200006_PID_R7_21_09_22_1200KLD_ALOK-INDUSTRIES-LTD-1-2-1-_page_2_2048_1024_rot180_png.rf.4c049d6e925eb9770e43ef2e3d5bb63c.jpg
# 2200006_PID_R7_21_09_22_1200KLD_ALOK-INDUSTRIES-LTD-1-2-1-_page_2_2048_2048_png.rf.e51b332f324e39d296bbb153d174424c.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_10_1024_2048_rot180_png.rf.a9111eb162056a9493fdedd4fdfd65c2.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_10_3072_2048_png.rf.661c74eec76b7dce61e2169c51367bff.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_11_3072_2048_png.rf.14e7325e8138fed94e96584ad9adc17d.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_11_5120_3072_rot180_png.rf.c372b353ca4003d0a7e7c06bde90979f.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_12_3072_2048_rot180_png.rf.e5eeaa677b6dece1b097258cea14201a.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_12_5120_2048_rot180_png.rf.ee102b924414d8649e3213e6f5861b59.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_13_2048_0_rot180_png.rf.7c4cb2b65f0853ba8ecbace3f0ca9671.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_13_2048_1024_rot180_png.rf.ced921a2a3902729dcd2b4a452c895d1.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_13_2048_3072_png.rf.16ef1502f731cbe9020a5cc4129252d4.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_14_1024_2048_png.rf.a6669e75e339bac41f2128e5bcfc4a02.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_14_1024_2048_rot180_png.rf.c4caa1c4246cfda37e606f358ec194b6.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_14_4096_0_rot180_png.rf.f7e548f90768a835737fb5e977f68326.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_15_1024_0_png.rf.4deff8286edf0b5562f47feb3f265bca.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_15_1024_2048_png.rf.84da7276285055c39e50c2af12d66301.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_15_2048_1024_png.rf.1ed64d30094a357e48d416237ee8c313.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_15_4096_3072_png.rf.9328b4e978a9c1a2cd180a2581be43a5.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_2_1024_2048_rot180_png.rf.807c68df30307f185f652d688b64e08b.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_2_3072_2048_rot180_png.rf.0f6bfc3e1a7943c950e4d722ca68bd99.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_3_1024_2048_rot180_png.rf.d6dbbfcfbef3afbcdb2cf434a757454e.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_3_2048_2048_rot180_png.rf.cd6c6221d3c8e2c7014e818970fa299b.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_3_3072_2048_rot180_png.rf.d7cf5e0f70e81d9254322336ddabe348.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_4_1024_2048_rot180_png.rf.d3e72163e2ae41f66b7ff3c8bdb48100.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_4_2048_2048_rot180_png.rf.ca4b40015206b940bcb4284b14712905.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_6_1024_1024_rot180_png.rf.b199975a23fdfde0473e12ac5094ea95.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_7_3072_1024_png.rf.16087032159dfa35254a3219737f6633.jpg
# 2200012_PID_R4_31_07_23_500-KLD-ERS-MRF-TYRES-LIMITED-A-1-TO-17_page_9_2048_2048_rot180_png.rf.f674ccc39916dcb92dfa1eb7966f140d.jpg
# 2200020_P-ID_REV04_18_03_24_-AEQUES-CONSUMERBELGAUM_ETP-ERS-1-TO-8_page_2_1024_1024_rot180_png.rf.79bbe7ac5b4b3c2da983b846c82fbc13.jpg
# 2200020_P-ID_REV04_18_03_24_-AEQUES-CONSUMERBELGAUM_ETP-ERS-1-TO-8_page_4_1024_1024_rot180_png.rf.e55c08d25720aea21227e64c04ac807b.jpg
# 2200020_P-ID_REV04_18_03_24_-AEQUES-CONSUMERBELGAUM_ETP-ERS-1-TO-8_page_5_0_0_rot180_png.rf.c03812d65912296a9e9d070f9a58f401.jpg
# 2200020_P-ID_REV04_18_03_24_-AEQUES-CONSUMERBELGAUM_ETP-ERS-1-TO-8_page_5_2048_0_rot180_png.rf.60e7908cb80714d882767c2873f9ff4d.jpg
# 2200020_P-ID_REV04_18_03_24_-AEQUES-CONSUMERBELGAUM_ETP-ERS-1-TO-8_page_7_1024_1024_png.rf.5dd878d15f5a6b6111421a83b32599b0.jpg
# 2200020_P-ID_REV04_18_03_24_-AEQUES-CONSUMERBELGAUM_ETP-ERS-1-TO-8_page_7_3072_2048_rot180_png.rf.5c25263d494ae4c323d3b9f86f81ac1e.jpg
# 2200020_P-ID_REV04_18_03_24_-AEQUES-CONSUMERBELGAUM_ETP-ERS-1-TO-8_page_8_2048_0_png.rf.cc70a0e296d3151045ff6d916408196f.jpg
# 22-0032_MEP_04-26-24_page_3_grid_1x1_jpg.rf.fe3f0ee4494948f9ebe1287ee73e3b3f.jpg
# 23-0003_MEP-Drawings_Issue-for-Bid_04-15-24_1_page_2_grid_2x1_jpg.rf.b40d7433ed7f392a7bc61d02bb5df636.jpg
# 23-0808-Glowbar-JERSEY-CITY-NJ-24X36-HVAC-Set_page_5_grid_2x3_jpg.rf.093f9c4c46231247d104c3c91029ba7e.jpg
# 23-10-20-M-Social-3rd-Floor-Drawing-Issue_1_page_47_grid_2x1_jpg.rf.052f75c6e0220a5b0f23f044eb674081.jpg
# 23-10-20-M-Social-3rd-Floor-Drawing-Issue_3_page_24_grid_1x3_jpg.rf.56c3447a023e149a81f7c8af085f1b3f.jpg
# 23-10-20-M-Social-3rd-Floor-Drawing-Issue_3_page_46_grid_1x3_jpg.rf.68c911a0b351835980b5e160f4efe608.jpg
# 23-10-20-M-Social-4-5-Drawing-Issue_3_page_49_grid_1x3_jpg.rf.3550cabfd3b2103512abc865d8ebd240.jpg
# 23_10_31-1148-5th-Mechanical-Board-Review-Rev2_page_2_grid_1x2_jpg.rf.cc7d05ebc4e67dc37602b815d7fa8188.jpg
# 23_10_31-1148-5th-Mechanical-Board-Review-Rev2_page_2_grid_3x1_jpg.rf.0dca1289c2c5629d0fa6cf0a8fa98a16.jpg
# 23_781-240808-285-CPW-10S-Shop-Drawings-Submittal-7-29-24_1_page_2_grid_2x1_jpg.rf.10bf68df25b7be43b07872357e25d337.jpg
# 24-0501_Wonder_Midtown_90-Set_Combined_page_31_grid_1x3_jpg.rf.8f3506d305c3f52d03ec0d9575da9442.jpg
# 24-0501_Wonder_Midtown_90-Set_Combined_page_31_grid_2x2_jpg.rf.ee194569045f2cf58734557d71ee1b6d.jpg
# 24-0611_Citibank-East-Williamsburg-HVAC-Set_1_page_3_grid_1x2_jpg.rf.4bce0e62809b8c627aba7c5faec8b31b.jpg
# 24-0611_Citibank-East-Williamsburg-HVAC-Set_1_page_3_grid_2x3_jpg.rf.7a2a2eafa198451ab14555b7adc5f93d.jpg
# 25-Kent-3rd_FL_CON_02_Issued-for-Filing-04_18_24-HVAC-Set_page_2_grid_2x1_jpg.rf.6e861b5302aeeddbfc56ee7fcf96ee86.jpg
# 25-Kent-3rd_FL_CON_02_Issued-for-Filing-04_18_24-HVAC-Set_page_2_grid_2x2_jpg.rf.37028c97c8a705b104cb767a023d2da7.jpg
# 25-Kent-3rd_FL_CON_02_Issued-for-Filing-04_18_24-HVAC-Set_page_2_grid_2x3_jpg.rf.66f5563b4dac61618e6d27b34dae37b7.jpg
# 25-Kent-6rd_FL_Add-No_3-Arch-MEP-Combined-Not-shared-yet_page_6_grid_1x3_jpg.rf.49ad4df8b0f3810026dd487a9abfb7a4.jpg
# 25-Kent-6rd_FL_Add-No_3-Arch-MEP-Combined-Not-shared-yet_page_6_grid_2x1_jpg.rf.fb6b42610dfe2c0a9f46aafa18853128.jpg
# 25-Kent-6rd_FL_Add-No_3-Arch-MEP-Combined-Not-shared-yet_page_6_grid_3x3_jpg.rf.7e9e8fcb1c157992ff1a4071f357a453.jpg
# 2_-Axinn-Issued-for-Bid-Filing-MEPS_-240510-HVAC-Set-Rev-1_1_page_4_grid_3x1_jpg.rf.a3ccfe363d1669ea8e949ef395cdf5c3.jpg
# 2GCT_31FL-MESIROW_ISSUED-FOR-BID-DOB-FILING-HVAC-Set_page_6_grid_1x1_jpg.rf.e50439e1b4ec5670b7ca3c3681758a23.jpg
# 2-GCT-floors-4-6-14-6th-Floor-HVAC_page_1_grid_1x1_jpg.rf.8d56bd2af488c1c6425ad4be49aee9c1.jpg
# 307W38TH-ST-ISSUE-FOR-BID-Mechanical_1_page_2_grid_1x3_jpg.rf.a01009b42d2ce1dbf8e790a4c487adf0.jpg
# 307W38TH-ST-ISSUE-FOR-BID-Mechanical_1_page_2_grid_2x3_jpg.rf.3834b2f5a5d6bcb550f8830e114913e2.jpg
# 327-Broome-Street-Mechanical-Contract-Drawings-6-14-23_page_1_grid_2x1_jpg.rf.cb9dc49a03e4ee8ffd83f1d7e392a691.jpg
# 41_14640_01_01_png.rf.27b4f4bf69889499d4afe8d2db26eb8e.jpg
# 610233-GGL-PID_R8-For-Pani_page_11_0_1024_rot180_png.rf.5f26a3ec8a37bd05a8a14e892bfeed0f.jpg
# 610233-GGL-PID_R8-For-Pani_page_11_3072_0_png.rf.4e31b9cd0741b8cde2c2d118b4910167.jpg
# 610233-GGL-PID_R8-For-Pani_page_12_2048_1024_rot180_png.rf.4a8d40fa7cfce696cecb1189dbbbdd13.jpg
# 610233-GGL-PID_R8-For-Pani_page_13_1024_1024_png.rf.b1170ef1f4e26766f86b9b360606acee.jpg
# 610233-GGL-PID_R8-For-Pani_page_15_3072_1024_rot180_png.rf.f53657a6bacfdb8b667169a6f7f2749a.jpg
# 610233-GGL-PID_R8-For-Pani_page_17_3072_1024_png.rf.0ee956cee97e9fcb4d4a2d2e065aee32.jpg
# 610233-GGL-PID_R8-For-Pani_page_18_1024_0_png.rf.cc59e524b849b42db02d236c602da070.jpg
# 610233-GGL-PID_R8-For-Pani_page_18_2048_0_rot180_png.rf.6a4514613959d8f17fbae915da4ebed3.jpg
# 610233-GGL-PID_R8-For-Pani_page_20_1024_1024_png.rf.cd2726665654fb91fd809aa07d64be48.jpg
# 610233-GGL-PID_R8-For-Pani_page_20_2048_2048_png.rf.88628f6fea5eb07383c4ed901e07326f.jpg
# 610233-GGL-PID_R8-For-Pani_page_22_4096_1024_rot180_png.rf.9022ee4e9a6a5799820d4f9976ea05ca.jpg
# 610233-GGL-PID_R8-For-Pani_page_25_2048_1024_png.rf.4e8f61793c964b455f05987894633d0a.jpg
# 610233-GGL-PID_R8-For-Pani_page_4_3072_1024_rot180_png.rf.bbd60de73c279aef7a7be4e172c18a9d.jpg
# 610233-GGL-PID_R8-For-Pani_page_7_3072_1024_png.rf.d325ac4b304f041003d6e1bd4f16787e.jpg
# 610233-GGL-PID_R8-For-Pani_page_9_0_1024_png.rf.74c677417b88cc7bc05834860da1fa39.jpg
# 750800000_PID_R0_14_4_25_165KLD_STP_BIRLA_ALOKYA_page_1_1024_2048_rot180_png.rf.5c87bf8e55535ea526ebbe5d59ae2207.jpg
# 750800000_PID_R0_14_4_25_165KLD_STP_BIRLA_ALOKYA_page_1_2048_2048_png.rf.5df750ecd348d9df8a6537d74d01310a.jpg
# 750800000_PID_R0_14_4_25_165KLD_STP_BIRLA_ALOKYA_page_1_3072_1024_rot180_png.rf.ae893bae1520d58b012436919b290b62.jpg
# 750800000_PID_R0_14_4_25_165KLD_WTP_BIRLA_ALOKYA_page_1_3072_0_png.rf.066b03f0deaad7ee5ad492f3ac8e410d.jpg
# 777-17-26_BidSet_03_25_24-HVAC-Set_1_page_8_grid_2x3_jpg.rf.1df66a3997b164fd807f17d153fe92c9.jpg
# 777-17-26_BidSet_03_25_24-HVAC-Set_1_page_8_grid_3x1_jpg.rf.277f2571f6a84c7301488f0288c58dae.jpg
# _annotations.coco.json
# COCA_page_1_1024_0_png.rf.75c457f37c87dde4c0ee999520a55857.jpg
# COCA_page_1_1024_0_rot180_png.rf.a9fac353cfefa9c8966d1aab45d423e2.jpg
# COCA_page_1_3072_0_png.rf.841784fb8db2c30dd6706f6e58b9f262.jpg
# COCA_page_2_1024_1024_rot180_png.rf.027b5e022a9e7a6c58478f86273826b5.jpg
# COCA_page_2_2048_0_png.rf.c38ad43b4707b534b288ca43d71c1364.jpg
# COCA_page_3_2048_0_png.rf.c36f2cf0bdf4ffa74fdeea7702095f71.jpg
# COCA_page_3_3072_0_png.rf.701f93d7c0bb808f6f812da8a3d52be7.jpg
# COCA_page_3_3072_0_rot180_png.rf.c534d5f025a948ce2c82f940aa4c94e5.jpg
# data13_png.rf.952c27c5b43ab7a9b13baa3487d3aa70.jpg
# data19_png.rf.71b8ef66171fd5c6d7d140e1758091f4.jpg
# data8_png.rf.2ed841f85dc09b13d59bab5c69f8c148.jpg
# ERCP_10_r0_c2_png.rf.5da2604c48752398d3abeb1d8283240c.jpg
# ERCP_10_r1_c1_png.rf.ad2faff4966753a32ae58a419b707e1f.jpg
# ERCP_10_r1_c4_png.rf.c39ee286696f2da500dfbedf00680775.jpg
# ERCP_10_r2_c2_png.rf.bd6ee96e91c76039d1f91cd0316d8cd6.jpg
# ERCP_11_r1_c2_png.rf.0cb5ff518237c39a5952676ee1aae688.jpg
# ERCP_11_r1_c2_png.rf.bf29c3dbc77858c1a9c72a78cd82d9cf.jpg
# ERCP_11_r1_c3_png.rf.2642558c4b8569a252ab0dd6f83c6975.jpg
# ERCP_11_r2_c4_png.rf.c8c2fc00ba3e64dc7f11190e228148a4.jpg
# ERCP_11_r3_c1_png.rf.56614b13cfb2e7ebc6e229de9f140063.jpg
# ERCP_11_r3_c4_png.rf.f92834b27dd39b9845d9ce7a85806d66.jpg
# ERCP_12_r1_c3_png.rf.8b0aaa06d9f8364c42ab1a006907ca5c.jpg
# ERCP_12_r2_c1_png.rf.041b98dee0ed1e352f91063f09303cc1.jpg
# ERCP_12_r2_c2_png.rf.5e487411df30bd6e4d287c7f65acd94b.jpg
# ERCP_12_r2_c3_png.rf.d35c29c52c16f93f254ab00f9d9306e2.jpg
# ERCP_12_r3_c1_png.rf.5fe6d49149170b7da438fb1b1a55f0a7.jpg
# ERCP_13_r1_c2_png.rf.4586244601f2fb2e6ee011b0097a677c.jpg
# ERCP_13_r2_c1_png.rf.8d486865803d7a29cfb78192b0d05288.jpg
# ERCP_13_r2_c2_png.rf.8bd87a478588c81777b9fdac3a65b045.jpg
# ERCP_14_r0_c3_png.rf.346ea3ee62bb5bd988d65a3f287ba24b.jpg
# ERCP_14_r1_c2_png.rf.f97c07ddb2216c9b144af2e15ebd421c.jpg
# ERCP_14_r3_c2_png.rf.77658ca06f5479bb2e71d893e0043339.jpg
# ERCP_15_r0_c1_png.rf.c947016a7d9fddd78d0f8b7e186f5fb0.jpg
# ERCP_15_r1_c2_png.rf.947ed8d65b708890edb31dfa1fea3fea.jpg
# ERCP_15_r1_c4_png.rf.ca99029f1308a6df0147bcf3847498ef.jpg
# ERCP_15_r2_c3_png.rf.f8d5ae2233037676dc91eec715d7785f.jpg
# ERCP_16_r0_c1_png.rf.40a368a34d0853bd071ca083ddf4db36.jpg
# ERCP_16_r0_c4_png.rf.5db020aa5770b4c14f8c6f92562781ec.jpg
# ERCP_16_r1_c3_png.rf.999fa18447b1b965d0972d41f9206f25.jpg
# ERCP_16_r2_c4_png.rf.ad960d61f0e8accd3992aca23f63ec44.jpg
# ERCP_17_r1_c4_png.rf.dfaef9e694b7a2bd2cb8019b23d7db6d.jpg
# ERCP_17_r2_c1_png.rf.60eb48a9bcac020ebd188c1cccb9086d.jpg
# ERCP_17_r3_c1_png.rf.b677e5efdfe933abf649fb62a3d4188d.jpg
# ERCP_18_r0_c2_png.rf.e005c7cad7c487c97f7406ef15b1fcc1.jpg
# ERCP_18_r1_c1_png.rf.04c98114e3d9e69df7b6eda63952e75b.jpg
# ERCP_18_r2_c3_png.rf.a1675c5abb9087551bdd37bcdeb22c93.jpg
# ERCP_19_r0_c0_png.rf.8815b7a737d3aa3e816fb1cdf779a15f.jpg
# ERCP_19_r0_c2_png.rf.fde3829afd535b378adeb55ce94ae4c4.jpg
# ERCP_19_r1_c2_png.rf.23c00648872f6f0740eeb4564ce8d6da.jpg
# ERCP_19_r2_c2_png.rf.a35d82747dc0f2c83c7cb36b0e522755.jpg
# ERCP_20_r0_c3_png.rf.5dc2674059865ef28eca69b54613c770.jpg
# ERCP_20_r1_c3_png.rf.b6009645f308f1186eb140c184b0d4b5.jpg
# ERCP_20_r3_c0_png.rf.f901f210c1af95361a1d15146780d6cf.jpg
# ERCP_21_r1_c1_png.rf.250992910ca9600239090f53cb111387.jpg
# ERCP_21_r1_c1_png.rf.6edc8af24635796c472da06363318051.jpg
# ERCP_21_r1_c1_png.rf.b1232c36b4cd279790b654d9b134bfc7.jpg
# ERCP_21_r1_c4_png.rf.2590cb30a88b0f446370021206361017.jpg
# ERCP_22_r1_c2_png.rf.46ace58d7032278568b233a70b9987bb.jpg
# ERCP_22_r1_c4_png.rf.a5c0476a1c4bf93779466cb238bf1f3f.jpg
# ERCP_22_r2_c1_png.rf.2d8f163b9da213fa8eb80eded48268fa.jpg
# ERCP_23_r1_c4_png.rf.1e59caaa40ae09f97238663e42d01e40.jpg
# ERCP_25_r1_c1_png.rf.cda0481c09173baea13b8b9c8c601971.jpg
# ERCP_25_r1_c4_png.rf.3bf5b760fd8c2182b2df4d4a23b83540.jpg
# ERCP_25_r2_c0_png.rf.876a224c2a8aa58dc824687b28ff87a9.jpg
# ERCP_25_r2_c2_png.rf.26363bdf6bbcbaa4caf0f05f8da0268b.jpg
# ERCP_26_r2_c2_png.rf.7474757d8edb262e31a79389b37c0893.jpg
# ERCP_28_r0_c3_png.rf.2ffea7cab7b41f0c2d7e2271d337bcbc.jpg
# ERCP_29_r3_c2_png.rf.cb5eb794fe105c29d0fe443c44b0ba47.jpg
# ERCP_2_r2_c2_png.rf.c9e60bf0768a609429419caf58ac6d7e.jpg
# ERCP_2_r3_c4_png.rf.b08d69baf5b36d3e6ecad2b3d91082b3.jpg
# ERCP_31_r2_c4_png.rf.33fc792a98658aedaae2c64f1b29c430.jpg
# ERCP_32_r0_c3_png.rf.9e7d632cba5c1f5acfc91894ed4f87d3.jpg
# ERCP_34_r0_c1_png.rf.ce7cb42ef2928c245982c4d8eec0f781.jpg
# ERCP_36_r0_c3_png.rf.43e28152a926c3d68160661572532915.jpg
# ERCP_40_r2_c1_png.rf.82e10ea12cac919499c26d873f89edc8.jpg
# ERCP_41_r2_c2_png.rf.6b347287b8525d500510a6fdf8bd1bd6.jpg
# ERCP_44_r1_c2_png.rf.5b14cb1e52b0fa22cde37cca81ba374b.jpg
# ERCP_45_r2_c2_png.rf.b86f4ae1362c899b161ed0c05624e61a.jpg
# ERCP_46_r2_c2_png.rf.cd53187f139c52bb58bbd19cb4eda0b4.jpg
# ERCP_4_r1_c1_png.rf.1310f355e63bd9283ce3718b3015a0b1.jpg
# ERCP_4_r1_c2_png.rf.529f5ee313df3f877e6b041bfff1a04e.jpg
# ERCP_4_r3_c4_png.rf.aeeccc21bf960bece78001184fc364ea.jpg
# ERCP_6_r0_c3_png.rf.749a0d4d35e7f851fede4431432779fc.jpg
# ERCP_6_r1_c1_png.rf.404349ab1e2f6f064c8c3f519cc22786.jpg
# ERCP_6_r1_c2_png.rf.b634c7f6a24033b57200b7c023f3f4e1.jpg
# ERCP_8_r1_c1_png.rf.16334fa5224aac98ec2ec23cb29bdcb4.jpg
# ERCP_8_r2_c2_png.rf.6818f93d6b626ac5706b1c727b915149.jpg
# ERCP_9_r0_c4_png.rf.e65a3a6f5c2cc23a52a8800d74520df7.jpg
# ERCP_9_r2_c3_png.rf.362a7519b51d05ec867ec4cb55d629f6.jpg
# ERCP_9_r3_c1_png.rf.bfe2f7ce93a12b99542257ddd0b92161.jpg
# ERCPP_31_r0_c1_png.rf.00590edfc3f548b9e88d4ab6edbaba6b.jpg
# ERCPP_4_r0_c1_png.rf.f62661ef2c3236a6d54dfc93d9c072b3.jpg
# ERCPP_5_r1_c2_png.rf.1be1c58e817f62d0a9468fa1e702fd71.jpg
# ERCPP_6_r1_c2_png.rf.767fe46e8235e8a77c4d0df6b5e2f01e.jpg
# ERWA_5_r0_c1_png.rf.37caa2f6d79cc5468f7c499a6d2c354e.jpg
# Funan_10_r0_c1_png.rf.c39c18df645ec286a59d0fc08c53c079.jpg
# Funan_1_r0_c1_png.rf.3d69202252acf9b63f7e51bfe699aa89.jpg
# Funan_9_r1_c0_png.rf.bd8c25db6c5be29e5b36cda1c54a9789.jpg
# HVAC-Set-11_16_2023_Apple-Bank_Queens-Blvd_Bid-Set_page_4_grid_11_jpg.rf.d329399d29d0cffbdfd31cb9276a83f0.jpg
# HVAC-Set-240329_ICONIQ-CAPITAL_ISSUE-FOR-BID-AND-LANDLORD-REVIEW_page_8_grid_14_jpg.rf.52ef311a26d63c7a51fb88160d09fc33.jpg
# HVAC-Set-240329_ICONIQ-CAPITAL_ISSUE-FOR-BID-AND-LANDLORD-REVIEW_page_8_grid_15_jpg.rf.e3ce7585ad35505a4f631cef20868dc6.jpg
# HVAC-Set-240329_ICONIQ-CAPITAL_ISSUE-FOR-BID-AND-LANDLORD-REVIEW_page_8_grid_16_jpg.rf.c0865e35f629616af7ed6747609d7aee.jpg
# HVAC-Set-240329_ICONIQ-CAPITAL_ISSUE-FOR-BID-AND-LANDLORD-REVIEW_page_8_grid_19_jpg.rf.86596986b2f565d12cc97c50c730eba8.jpg
# HVAC-Set-24-0501_Wonder_Midtown_90-Set_Combined_page_2_grid_12_jpg.rf.0348adeceac3376d451790bc4dc7cad2.jpg
# HVAC-Set-24-0501_Wonder_Midtown_90-Set_Combined_page_2_grid_13_jpg.rf.565edca93d43c9d87e969c129d411ca0.jpg
# HVAC-Set-24-0501_Wonder_Midtown_90-Set_Combined_page_2_grid_18_jpg.rf.de393f2689f65abffe454fd9f70585d0.jpg
# Kith-Permit-Mechanical-6-14-2024_page_6_grid_8_jpg.rf.aaa9690b1caa829cfbf2c8fe50648448.jpg
# Kith-Permit-Mechanical-6-14-2024_page_6_grid_9_jpg.rf.9be81008e18e8bf06b604475a31c971a.jpg
# louvers-and-dampers-marked-HVAC-Set-1001-6th-Ave-11th-Issued-For-Pricing_page_3_grid_11_jpg.rf.f2aa4cf6f3001937c35a60934a8aed58.jpg
# louvers-and-dampers-marked-HVAC-Set-1001-6th-Ave-11th-Issued-For-Pricing_page_3_grid_6_jpg.rf.88dbfa50d28d72cf17fccc6b1c52b434.jpg
# louvers-and-dampers-marked-HVAC-Set-1001-6th-Ave-11th-Issued-For-Pricing_page_3_grid_8_jpg.rf.b470ff867bb2f3fa5f7efd233df366f7.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_11_grid_12_jpg.rf.2cbba282f9f653ed059e43b44b56063c.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_11_grid_17_jpg.rf.74914082ace7dd806b295bf2b65a4757.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_11_grid_19_jpg.rf.713eb9e9352cfb8b1ce9b8c0432ccb9c.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_11_grid_5_jpg.rf.54d7460e768d76dececc7bbad3fbcf8a.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_9_grid_3_jpg.rf.29bc75bd0138e84172953b8bdf81238e.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_9_grid_6_jpg.rf.000610b306ef10dea3986a4dce892454.jpg
# Mechanical-HVAC_1_page_10_grid_10_jpg.rf.83a3a7720414dc7b033d75af150a4205.jpg
# Mechanical-HVAC_1_page_10_grid_16_jpg.rf.c62ff0383fc5ce1f648eb25f6c1714ba.jpg
# Mechanical-HVAC_1_page_10_grid_18_jpg.rf.5052eb39ee9b4a2e662c9f8ab542ea36.jpg
# Mechanical-HVAC_1_page_10_grid_19_jpg.rf.7deec05c3c8d1e589da80d980661825f.jpg
# Mechanical-HVAC_1_page_10_grid_9_jpg.rf.a62bd3d46a3417a6701ef352ebee7d5f.jpg
# Mechanical-HVAC_1_page_9_grid_13_jpg.rf.6bf5ee0975042223059e198d4ecef54a.jpg
# MEP_Bulletin_-3_4th_Floor-DD_100-_page_4_grid_21_jpg.rf.d7fd050665c05c3d7bd2791a28509523.jpg
# MEP_Bulletin_-3_4th_Floor-DD_100-_page_4_grid_3_jpg.rf.b2acdd6ff6d2d8a6347e621464167e6b.jpg
# MEP-s-10239_2023-10-05_Progress-Set_page_30_grid_16_jpg.rf.5bceaf67f7f463118d16c9e9da7508f9.jpg
# MEP-s-10239_2023-10-05_Progress-Set_page_30_grid_7_jpg.rf.aa0ad5424a914d37c3cb76149eb715f7.jpg
# newdata113_png.rf.b1dde944bb14992f17a0d76be1d89221.jpg
# newdata18_png.rf.bd0d1342fc4e40adafff4fe993e19579.jpg
# newdata21_png.rf.007240a40a69b9d968a270334e7ce74b.jpg
# newdata25_png.rf.d1baeb5c8bea761f57130eb2e645018c.jpg
# newdata30_png.rf.a9ef1ed16ca8f6287e630c224666e125.jpg
# newdata33_png.rf.6e438b598729d99af82c30750a1e933c.jpg
# newdata49_png.rf.d72719cf8a9da78e5e0a6de64ceb9a73.jpg
# newdata57_png.rf.c9022134344b3ae1432f6f8c614dcf5a.jpg
# PCV-3_png.rf.6782feb359a3f2b6d232e7089d59ffc3.jpg
# Perspire-Studios-510-Driggs-HVAC-Set_page_8_grid_2_jpg.rf.803d9b8e33a36269430b6fad422c5150.jpg
# Phenix-Salon-Riverdale-MEPS_1_page_3_grid_1_jpg.rf.45fac71eb1fe5732ec1bbb79f2ffec9f.jpg
# Phenix-Salon-Riverdale-MEPS_1_page_3_grid_22_jpg.rf.8e0908258047a4ac352be95aac7e8483.jpg
# pid_00004_jpg_51_jpg.rf.5a5fc578c64f39c0ae902b45fdf8b602.jpg
# pid_00004_jpg_52_jpg.rf.1b8fd295cbe0c2aeb95a7a00b292b71c.jpg
# pid_00004_jpg_95_jpg.rf.9c9becd3ccf6a5c4ef2a2cdf4ef913dd.jpg
# pid_00005_jpg_28_jpg.rf.4162b9044f4200a3f1eb245447524493.jpg
# pid_00006_jpg_16_jpg.rf.e5c6374a0f32dd910d264da71a10a8fb.jpg
# pid_00006_jpg_27_jpg.rf.55557c79e7f2ed3e4c1984b1594541fd.jpg
# pid_00006_jpg_73_jpg.rf.3c23aa19d4deb53745c75fb7265d4393.jpg
# pid_00007_jpg_3_jpg.rf.b0d17a3f0d47ea1fbce1ed275711c798.jpg
# pid_00010_jpg_83_jpg.rf.6b77d43dbc992dac21a57f1f4b8d5a2f.jpg
# pid_00011_jpg_15_jpg.rf.63801dfe58392b114d7372f2c9cedc22.jpg
# pid_00011_jpg_51_jpg.rf.8bbc5a0b8a1bc09d67f107b8fc478150.jpg
# pid_00011_jpg_79_jpg.rf.2c9277f039a0489c1227472783d7b6db.jpg
# pid_00011_jpg_7_jpg.rf.55ccc50a4fca46e3c952c1f1ac352f33.jpg
# pid_00014_jpg_3_jpg.rf.22b9afaab5f385c8ba4455608354e1ce.jpg
# pid_00016_jpg_41_jpg.rf.3dd8a3e7f00f51dea89c5e4bf40a1948.jpg
# pid_00016_jpg_76_jpg.rf.c09722cdec0f3fdb3b9900513f659b83.jpg
# pid_00016_jpg_96_jpg.rf.01d92183891c870ef364e8a94e82a337.jpg
# pid_00021_jpg_19_jpg.rf.481cec8bb3d365eaff7028bdbd0ea933.jpg
# pid_00022_jpg_34_jpg.rf.6e3b8408094eed98a85010ba9dfcefc5.jpg
# pid_00024_jpg_8_jpg.rf.3f0b861cd24156bf3f6fde5ecd4121fa.jpg
# Platong_1_1_r0_c0_png.rf.8358ada8f5e5e33385e9ec7ca04e3468.jpg
# Platong_1_3_r0_c1_png.rf.c3a485fc23a1718495b5994e8e9aabf5.jpg
# Platong_2_2_r0_c0_png.rf.4a6e837f4e2b64fb63bd7d607d062f1c.jpg
# Platong_3_10_r1_c1_png.rf.8ef4ae354ccb5ee6e459b4cb01548808.jpg
# Platong_3_40_r1_c0_png.rf.a9fa75241b32fc22bb5438213d07a170.jpg
# Platong_3_45_r1_c0_png.rf.8a103fd09c4f6697314e660dfc8844da.jpg
# Platong_3_45_r1_c1_png.rf.0cf41fe23df64732512a6092fb64bb03.jpg
# Platong_3_45_r1_c1_png.rf.9a50397d90f8d2b92892b99e11b2099e.jpg
# Platong_3_49_r0_c1_png.rf.0eb945fdb84aaced850b385d1aef02ee.jpg
# Platong_3_55_r0_c1_png.rf.29ef8a6aa31e61faad71a4fe71f7dd1c.jpg
# PLUG-1_png.rf.5ea753eaa198c734685b33e9502d826d.jpg
# POC-1_png.rf.507bd2c837fcb2533b5ac09445002386.jpg
# POC-3_png.rf.4d786d1cb2b920c37ce47f625267bfa0.jpg
# preview16_png.rf.0067069e1f1017f676fa6ccf769c420c.jpg
# preview21_png.rf.28f4661089eddc3b9abf87697d2d779e.jpg
# preview23_png.rf.1d6373c211bcfd67cbe36341c02b2515.jpg
# preview27_png.rf.f85e1de5725f91f0de72bb95b64159bc.jpg
# preview32_png.rf.972f4352d9872d8d8cad18cf8dd321bb.jpg
# preview34_png.rf.9457e3235a4374e04dce22523b189666.jpg
# preview48_png.rf.61f00f07a34404e5ea76d921e0e898e6.jpg
# preview6_png.rf.879a4c59ce136268fb0cbfc2378f8cd9.jpg
# preview7_png.rf.7fe406823caf087925fa358d229753ee.jpg
# Reznor-Ducted-Heater-Submittal-SE-Review_page_11_grid_13_jpg.rf.ed2b9e1596bcf605c6d37f8a6da0bb72.jpg
# Reznor-Ducted-Heater-Submittal-SE-Review_page_11_grid_15_jpg.rf.ad0070aea82a77f8c6cc75193b709d1f.jpg
# Reznor-Ducted-Heater-Submittal-SE-Review_page_11_grid_23_jpg.rf.c8acefa7dd94936456b3e8b37f2c783b.jpg
# Rudin-HVAC-Set_page_5_grid_7_jpg.rf.de98d2e4f3a9ceb169caf2bfbcc89067.jpg
# Sample_a_2_patch_6_png_jpg.rf.480b0dcd8e9f7f675dc63aefe7ef4d03.jpg
# Sample_a_3_patch_4_png_jpg.rf.1fb2cecfe643b9803a7d5bc612740311.jpg
# Sample_a_3_patch_7_png_jpg.rf.98ac489a64098198c17d585b42c37ac2.jpg
# Sample_a_4_patch_0_png_jpg.rf.be0b79874038be11d3a49dee57126125.jpg
# Sample_a_4_patch_1_png_jpg.rf.46c67f8bdbad6bfc218ef6d506406de6.jpg
# Sample_a_4_patch_4_png_jpg.rf.ac3b94b5b85088c9b4426a3986b24d05.jpg
# Sample_a_4_patch_6_png_jpg.rf.2cfee68a48341620df89b396f04b0dcf.jpg
# Sample_b_1_patch_0_png_jpg.rf.df1650d0f633f398dfb3f1a7af30761a.jpg
# Sample_b_1_patch_5_png_jpg.rf.369e7ec8ed04efe46b3b51a42605f500.jpg
# Sample_b_2_patch_0_png_jpg.rf.ce7e210a00468804af6274fb9e6e3dba.jpg
# Sample_b_3_patch_5_png_jpg.rf.d5f0a429514e45e2a3c45c3f992e3bfa.jpg
# Sample_b_4_patch_5_png_jpg.rf.6f601c57289c5dd4401a5390704ef8f2.jpg
# Sample_b_5_patch_2_png_jpg.rf.80c1d391e7535e2c6a9c83861ddcc8c6.jpg
# Sample_c_3_patch_1_png_jpg.rf.d1070dd6b046c1fbffd18d42f61d8015.jpg
# Sample_c_4_patch_4_png_jpg.rf.38536871554ae0a185e5fd373047e1ab.jpg
# Sample_c_5_patch_0_png_jpg.rf.96130ce2c1a6ca8285d41c4845c760c8.jpg
# Sample_d_2_patch_6_png_jpg.rf.882d176db28614427c6aba4ef2eec8fd.jpg
# Screenshot-2025-08-06-071350_png.rf.f938de19b328bb23dcee867c6941e82d.jpg
# Screenshot-2025-08-06-073248_png.rf.50ef6eba975087b895f75c4dba9638c3.jpg
# Screenshot-2025-08-06-073319_png.rf.7c3f86d288e818ce0136b73cc9c8f7af.jpg
# Screenshot-2025-08-06-073408_png.rf.f509f1f3298071da9971ddce3fbdbb60.jpg
# Screenshot-2025-08-06-073811_png.rf.9e0a8cf562191f9f191490e7ff51047a.jpg
# Screenshot-2025-08-06-073819_png.rf.7c35fd586ed49b5a7952f009a5777f17.jpg
# Screenshot-2025-08-06-073831_png.rf.41ec710a2d0080f0534389bf44d0ab79.jpg
# Screenshot-from-2022-10-04-10-24-55_png.rf.1bc7a2b66204a04b1bc29eda912919f8.jpg
# Screenshot-from-2022-10-04-10-25-21_png.rf.405b752d5f65bc0156ec5d849b8c1f26.jpg
# Screenshot-from-2022-10-04-10-28-12_png.rf.740704b1ac49464690d31e456a13589d.jpg
# Screenshot-from-2022-10-04-10-29-17_png.rf.75fad6b053147c3cac0ae58be4f78355.jpg
# Screenshot-from-2022-10-04-10-31-04_png.rf.86eb3fa51a4977445aa64090bae1c7a4.jpg
# Screenshot-from-2022-10-04-10-31-10_png.rf.47e9dfde23827b530816748b9682b2af.jpg
# Screenshot-from-2022-10-04-10-31-42_png.rf.63e1698cfd27b6685bc592abae1377f9.jpg
# Screenshot-from-2022-10-04-10-33-08_png.rf.11203a972b72f3e0b41befaf17bfb093.jpg
# Screenshot-from-2022-10-04-10-34-01_png.rf.f74f4cf382b8ce648874e898ffdd1a7f.jpg
# Screenshot-from-2022-10-04-10-37-01_png.rf.09033482cbf57653e749902d15651fe6.jpg
# Screenshot-from-2022-10-04-10-39-21_png.rf.9542661338dc2df94175d846945b6e78.jpg
# T00106018_mechanical_bid-filing_20240402-HVAC-Set_1_page_7_grid_1_jpg.rf.aed56e9cf0de50eaee752c2d0800eb94.jpg
# T00106018_mechanical_bid-filing_20240402-HVAC-Set_1_page_7_grid_22_jpg.rf.133ad136f6c087a3a35e55d11ee4c839.jpg
# TISHMAN-1-ROCK-5FL-ARCH-MEPS-IFB_021524_2_page_37_grid_2_jpg.rf.c7b05337c6144ab080fd6e1a1c0a996b.jpg
# TRI-EC-BEA-PR-12-53-4036-1-2-a_jpeg.rf.19d1fc903497c241f79a722e83d70ade.jpg
# TRI-EC-BEA-PR-12-53-4037-A_jpeg.rf.36bb98badc8229e70539025dfd178fc7.jpg
# TRI-EC-BEA-PR-12-53-4038-2-3-A_jpeg.rf.94bb679c82fbb8c3a8bec8e6669556e4.jpg
# TSP-666-3rd-Ave-14th-Floor-Terrace-and-Prebuild-Addendum-1-Arch-3_4_24_1_page_14_grid_11_jpg.rf.7d841b01389ce359669f71ea00dfc242.jpg
# TSP-666-3rd-Ave-14th-Floor-Terrace-and-Prebuild-Addendum-1-Arch-3_4_24_1_page_14_grid_17_jpg.rf.60b971cc69e71a790c7cc86c0d2a17c0.jpg
# TSP-666-3rd-Ave-14th-Floor-Terrace-and-Prebuild-Addendum-1-Arch-3_4_24_1_page_14_grid_21_jpg.rf.33410125368df808466ba13919264072.jpg
# TSP-666-3rd-Ave-14th-Floor-Terrace-and-Prebuild-Addendum-1-Arch-3_4_24_1_page_14_grid_23_jpg.rf.cbfc99a6bda1d4d7978bfec9cacebbdf.jpg
# Warby-Parker-New-York-NY-Bid-Set-12-6-24_page_37_grid_2_jpg.rf.8c47933310a76c0cd26ff1b58b0cd1ff.jpg
#
# /content/drive/MyDrive/hvac_dataset_coco/train:
# 02_20240401_2GCT_31FL-MESIROW_ISSUED-FOR-ADDENDUM-01-HVAC-Set_1_page_6_grid_1x2_jpg.rf.bf26b96a29a7217f242a766c34b7f1b9.jpg
# 02_20240401_2GCT_31FL-MESIROW_ISSUED-FOR-ADDENDUM-01-HVAC-Set_1_page_6_grid_2x1_jpg.rf.9f420932e017f5da7aa3149d3ace43b2.jpg
# 02_20240401_2GCT_31FL-MESIROW_ISSUED-FOR-ADDENDUM-01-HVAC-Set_1_page_6_grid_2x3_jpg.rf.7b3f66d08086ad312add09d00ae8c3c9.jpg
# 02_20240401_2GCT_31FL-MESIROW_ISSUED-FOR-ADDENDUM-01-HVAC-Set_1_page_6_grid_3x3_jpg.rf.a3d93675608430ad672f1b0d67e4c922.jpg
# 03-Mechanical_1_page_4_grid_1x1_jpg.rf.cfa59d4b67784902a2e7b17a295de944.jpg
# 03-Mechanical_1_page_4_grid_1x2_jpg.rf.9f843022fff48df84d522c2938842ff4.jpg
# 03-Mechanical_1_page_4_grid_2x1_jpg.rf.c6de3375e116ba4ae614abd7669e9a68.jpg
# 03-Mechanical_1_page_4_grid_2x2_jpg.rf.ab6d57e772a2d7463ebb34933164fc9a.jpg
# 03-Mechanical_1_page_4_grid_2x3_jpg.rf.df4ebf3cf31f4e8017410304e57beec0.jpg
# 03-Mechanical_1_page_4_grid_3x1_jpg.rf.fc889b627b63ca3ba595619691401b93.jpg
# 03-Mechanical_1_page_4_grid_3x3_jpg.rf.069290d7594046ad2befe9f04605d7f4.jpg
# 03-Mechanical_1_page_5_grid_1x1_jpg.rf.78b08f0a6fff3b5a40842202362dab19.jpg
# 03-Mechanical_1_page_5_grid_2x2_jpg.rf.1f9cf9b18082c3dad7708ff246d5ef59.jpg
# 03-Mechanical_1_page_5_grid_2x3_jpg.rf.6a5acd3cd4385cb1aa6458e0e60bf6d2.jpg
# 03-Mechanical_page_6_grid_1x1_jpg.rf.14ba8ffaadea280a1292a51273b0250a.jpg
# 03-Mechanical_page_6_grid_1x2_jpg.rf.2c7c764345bafa6f5085dd583429a19a.jpg
# 03-Mechanical_page_6_grid_1x3_jpg.rf.1bf87455724c2ddec53e5f7e90814a8f.jpg
# 03-Mechanical_page_6_grid_2x1_jpg.rf.d8590d4fb89830464775fc718f08f17c.jpg
# 03-Mechanical_page_6_grid_2x2_jpg.rf.e8cd24940ef585c1c0647d56663cc88d.jpg
# 03-Mechanical_page_6_grid_2x3_jpg.rf.da2493ab9dbc9d49ada9334d8916d96f.jpg
# 03-Mechanical_page_7_grid_1x1_jpg.rf.4037ef4de723c404fa564630889f9e36.jpg
# 03-Mechanical_page_7_grid_1x2_jpg.rf.1d406106af2709198dcdd248b1f75c12.jpg
# 03-Mechanical_page_7_grid_1x3_jpg.rf.997181cd53154b8d9d787593373fc01b.jpg
# 03-Mechanical_page_7_grid_2x2_jpg.rf.d2597577d09d5b5d2ce2764335221ec0.jpg
# 04_-M-P-Set-04_04_2024_page_1_grid_1x2_jpg.rf.f637c3607932528bebf75180e7c4fad0.jpg
# 04_-M-P-Set-04_04_2024_page_1_grid_2x2_jpg.rf.1a4c5b8b60907516d1978577a3bd6543.jpg
# 04_-M-P-Set-04_04_2024_page_1_grid_2x3_jpg.rf.93854759fe845457329d4e546b91eed9.jpg
# 04_-M-P-Set-04_04_2024_page_1_grid_3x2_jpg.rf.00ce01d4c675b90026f076c53d8cda3a.jpg
# 0510102022_png.rf.e99abb6323676d05cd23599e4d3bd292.jpg
# 0510112022_png.rf.5da471fb90c75f5f641a88bc59cd6af9.jpg
# 051012022_png.rf.b8f04518febd66c22eb912856ed9292d.jpg
# 0510122022_png.rf.60b4262ec663dfdc0e67aeb91f4b490f.jpg
# 0510132022_png.rf.93f6e4aa52078eceaca105681e3444ef.jpg
# 0510142022_png.rf.4e939727203951122c823d73ad58db2f.jpg
# 0510152022_png.rf.14515f51bdcfe15ba1bf3d8f71d189e6.jpg
# 0510172022_png.rf.b7a945c000724d4d1e1a550f274540bc.jpg
# 0510182022_png.rf.aca9916500e3f387ab7aa28bb8edb6cb.jpg
# 0510192022_png.rf.93360ccf8461a462792d4a4cfcd35f1b.jpg
# 0510202022_png.rf.ca554227661165c7456dfc1e24f9dd45.jpg
# 0510212022_png.rf.4bd836a9a3b525162ad659f58e9bc87f.jpg
# 051022022_png.rf.4d7aeee4304c60130612ca9d5ff74eea.jpg
# 0510222022_png.rf.ff76fc0308020180d70b0965c9c870a4.jpg
# 0510232022_png.rf.fa3211d14200c50d62dba9ba3263bf55.jpg
# 0510242022_png.rf.787c1b75a266a5437203f09d5aed741a.jpg
# 0510252022_png.rf.bcaaf212d1ffa2d02c93d55b676275eb.jpg
# 0510262022_png.rf.ea738e2af5a4780597f8f9031fd5823c.jpg
# 0510272022_png.rf.ecf87a48f864151575ccc11d9b511ebd.jpg
# 0510282022_png.rf.4ff5d9cfc02ceba085d87ad0c6c1a632.jpg
# 0510292022_png.rf.48d2404144befd900c56607dce670d7d.jpg
# 0510302022_png.rf.89f1191bc2c58ff1b561a817596f67b0.jpg
# 0510312022_png.rf.269cee0cffc2928f3c1d1ec9081ac788.jpg
# 0510332022_png.rf.126da73b045a845d3111daf026918615.jpg
# 0510352022_png.rf.41c830e353fcb6f61898a40d42341df7.jpg
# 0510362022_png.rf.1c3e72d4aa4d63e685d8e2b022304f04.jpg
# 0510372022_png.rf.9a7cd3328825db1a095367731bf9a8d9.jpg
# 0510402022_png.rf.8cf621569712394d85daa9df218c8d2a.jpg
# 0510412022_png.rf.38d10a7d90b39fffe5d6c4dd62da29c4.jpg
# 051042022_png.rf.cb69e6f80f39fe9afe586ab9d7835a82.jpg
# 0510422022_png.rf.812392d2ae1ca4dd3bc3aaf1ba0392df.jpg
# 0510432022_png.rf.ca5492a0c3756434cdce173189aa08a0.jpg
# 0510442022_png.rf.a66c984fbefc96110f06f0beb4418ee6.jpg
# 0510452022_png.rf.140852e432adf8d663068ba3b20605eb.jpg
# 051052022_png.rf.dbe0d4b3b0e396a8c67fe9ecea9be68d.jpg
# 051062022_png.rf.bcb2b32cee41aa0d4f264a8e90c67ead.jpg
# 051072022_png.rf.815c72f6010e57a30aeb7c283cba3eeb.jpg
# 051092022_png.rf.9c1bc470527e335b7a7df9fe3e8ecd72.jpg
# 07102022110_png.rf.5008027187a2b444ecbb8d43e5ac0c47.jpg
# 07102022112_png.rf.314d8b675d76de27e5db476ed8931a4c.jpg
# 07102022115_png.rf.5422a59cf4233df568a45792221ea42a.jpg
# 07102022116_png.rf.65fc26c50115fdb29977daffe6b7f21c.jpg
# 07102022117_png.rf.e2156c15c8b2a7f10d2d3510374de563.jpg
# 07102022118_png.rf.f5bcf07af0cc9ce0314d38c53d8e46e6.jpg
# 07102022119_png.rf.6df99aaacf2d681725a60208323ed164.jpg
# 0710202211_png.rf.e3a0274e6e6e6b56f708e3bb09cf4fac.jpg
# 0710202212_png.rf.9af69427af33527a6197cdabbe0e55cb.jpg
# 0710202213_png.rf.52e1b8f659fa5f6679990029de2e5305.jpg
# 0710202214_png.rf.edd61bb653c93a0e2dcfa6ca811cb501.jpg
# 0710202215_png.rf.9912980a59f50f9c475afff053583d07.jpg
# 0710202216_png.rf.6689edd051b3ec9e3e273784c755867d.jpg
# 0710202217_png.rf.c21c756a4c3835c738077cf02a75bdeb.jpg
# 0710202218_png.rf.4e53d9576cc63082e728d7e88eda0d95.jpg
# 0710202219_png.rf.89f05e29953ecddbd44ee0ac03928b17.jpg
# 08_04_23-32-East-57th-Street-3rd-Floor-Mechanical-22573_1_page_3_grid_1x1_jpg.rf.f6d17cbfa38138e0c45d39b7af3eda28.jpg
# 08_04_23-32-East-57th-Street-3rd-Floor-Mechanical-22573_1_page_3_grid_1x2_jpg.rf.a7b9d29364d070a63ef8ac37d2d3aed0.jpg
# 08_04_23-32-East-57th-Street-3rd-Floor-Mechanical-22573_1_page_3_grid_2x1_jpg.rf.f96cc8c7bcac764ab826ff1d4322d214.jpg
# 08_04_23-32-East-57th-Street-3rd-Floor-Mechanical-22573_1_page_3_grid_2x2_jpg.rf.eaaf8979b27997e003a5e7ce00230940.jpg
# 08_04_23-32-East-57th-Street-3rd-Floor-Mechanical-22573_1_page_3_grid_3x1_jpg.rf.b110eaaa4d770c0a20d56b68440869c0.jpg
# 08_04_23-32-East-57th-Street-3rd-Floor-Mechanical-22573_1_page_3_grid_3x2_jpg.rf.d8c99ad14ec6fad0b1eaf77524358801.jpg
# 1001-6th-ave-3rd-FL-SUITE-300-ISSUED-FOR-BID_1_page_9_grid_1x2_jpg.rf.547ef78427c30d52461d2c898d81899f.jpg
# 1001-6th-ave-3rd-FL-SUITE-300-ISSUED-FOR-BID_1_page_9_grid_2x1_jpg.rf.2c4073f8421d55726186c9c98afd7b5d.jpg
# 1001-6th-ave-3rd-FL-SUITE-300-ISSUED-FOR-BID_1_page_9_grid_2x2_jpg.rf.4317dc019d9586d4e6d7b58c9ae836bd.jpg
# 1001-6th-ave-3rd-FL-SUITE-300-ISSUED-FOR-BID_1_page_9_grid_3x1_jpg.rf.4c88bf4475cbc46ba565963866ddc33f.jpg
# 1001-6th-ave-3rd-FL-SUITE-300-ISSUED-FOR-BID_1_page_9_grid_3x2_jpg.rf.0ab007df77266e269fd64e9a2381ee60.jpg
# 111-5th-Ave-Winter-Organization-HVAC-Set_page_8_grid_1x1_jpg.rf.d1138440d31e7497bfc3184157ee2f25.jpg
# 111-5th-Ave-Winter-Organization-HVAC-Set_page_8_grid_1x2_jpg.rf.fec1406b0d8e56d2338bc95f826e3fb9.jpg
# 111-5th-Ave-Winter-Organization-HVAC-Set_page_8_grid_1x3_jpg.rf.4fe0cb100da6741b2510cdb0bbc9a46e.jpg
# 111-5th-Ave-Winter-Organization-HVAC-Set_page_8_grid_2x2_jpg.rf.626e02b53cc2ebab0ed80e333ee04ce3.jpg
# 111-5th-Ave-Winter-Organization-HVAC-Set_page_8_grid_3x2_jpg.rf.ff9aba5ebd265f8d64899193a52d1bdd.jpg
# 1187-3rd-Warby-Parker-HVAC-Set_page_2_grid_1x1_jpg.rf.0f01754e1214162260a44ebb11a7c6c6.jpg
# 1187-3rd-Warby-Parker-HVAC-Set_page_2_grid_1x2_jpg.rf.5226ea00c51f9c57ef7e966647dc5f33.jpg
# 1187-3rd-Warby-Parker-HVAC-Set_page_2_grid_1x3_jpg.rf.61b1816baf28f16e630de16cd214a008.jpg
# 1187-3rd-Warby-Parker-HVAC-Set_page_2_grid_2x2_jpg.rf.35b94a45c4760562d7dbaa56f4cfd6f6.jpg
# 1187-3rd-Warby-Parker-HVAC-Set_page_2_grid_3x1_jpg.rf.fd509f1b17230a816bce57d1f33d71e8.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_0_0_png.rf.47d54772723ab4448b6d8aea8b47b7f2.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_0_0_rot180_png.rf.c7ca61b74315bf8d176619a9e6eb2535.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_0_1024_png.rf.6f2ece661630ddac100eaf0f592e6d39.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_0_1024_rot180_png.rf.7f02b10bcf1392c15040533e491858b0.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_0_2048_png.rf.aef04f1de66cf4e796e34d5de2bcb1e8.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_1024_1024_png.rf.0100dc0b4fadddc63d507164b7af2bc2.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_1024_1024_rot180_png.rf.3bf014ec96443bd520926370052f993e.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_2048_1024_png.rf.389ae658202bd828c628232fa902b057.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_2048_1024_rot180_png.rf.75830508b743bb68ce71a8e1aa89b1ef.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_3072_1024_png.rf.6660d2aeea3bb787425e26edbf91f121.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_3072_1024_rot180_png.rf.160716894cf535edfe000d7edf7bb4b1.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_4096_0_rot180_png.rf.50bd8e03b67e50cc7a0dc095dbcb3999.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_4096_1024_png.rf.72d5a229325c38dba95a710942a719af.jpg
# 1200246_P-ID_R1_31_12_2024_page_2_4096_1024_rot180_png.rf.0b36e1dfe64a278d9497767ec26368b2.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_0_1024_rot180_png.rf.43f77159ac0c0f6996e95d6819581bdb.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_1024_1024_png.rf.3ef244d0ae532304e98afd920fd0b113.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_1024_1024_rot180_png.rf.c65e62e85afe59a853c4fa359ad7e41a.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_1024_2048_png.rf.433d9d155772ef70cde9e8c2a49d1c11.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_1024_2048_rot180_png.rf.b0d6538ec310166821f46bc9e3ef7f39.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_2048_0_rot180_png.rf.ae7768758552c46cb37189a87ffbc804.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_2048_1024_png.rf.5abb24c63d0bd2981bd055ad18d1cab2.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_2048_2048_png.rf.cf796a39ffcca5b7da75060c954eeea7.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_3072_0_png.rf.9862eee942ddee1ff5b9e0155036f757.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_3072_0_rot180_png.rf.882627c573e4a77b3c0f963b037bf1e2.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_3072_1024_png.rf.4cdf7f67e96b6514099172eca252468b.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_3072_1024_rot180_png.rf.04d8c14120c2e2ab951a332b0e5f72c7.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_3072_2048_rot180_png.rf.c106c640d2ad8a275c1702f405773212.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_4096_1024_png.rf.53ce7509ce0375d0b61777783114e7ef.jpg
# 1200246_P-ID_R1_31_12_2024_page_3_4096_1024_rot180_png.rf.7be04b2e08d7507092220ceaa708ae85.jpg
# 1200246_P-ID_R1_31_12_2024_page_4_2048_1024_png.rf.4acc580c744d1ed8794c9f07f3f36bc9.jpg
# 1200246_P-ID_R1_31_12_2024_page_4_2048_1024_rot180_png.rf.b240fca8a166cc0cc4a8eceea255a7b9.jpg
# 1200246_P-ID_R1_31_12_2024_page_4_2048_2048_png.rf.1f9a6057f3ec6a38e1cef9c1209cc069.jpg
# 1200246_P-ID_R1_31_12_2024_page_4_2048_2048_rot180_png.rf.42ac63c49a43bee62c963747164491b2.jpg
# 1200246_P-ID_R1_31_12_2024_page_4_3072_2048_png.rf.5f79f16467adb1cf81686b11f317c9ce.jpg
# 1200246_P-ID_R1_31_12_2024_page_4_3072_2048_rot180_png.rf.b306e4333226b3995568852ea3d902c5.jpg
# 1200246_P-ID_R1_31_12_2024_page_5_0_2048_rot180_png.rf.061f2893fa15cc79c73368f8c100e710.jpg
# 1200246_P-ID_R1_31_12_2024_page_5_1024_2048_png.rf.58ea63ec4f3ce21096b936656be2e67c.jpg
# 1200246_P-ID_R1_31_12_2024_page_5_1024_2048_rot180_png.rf.c041bdc649cf944c1d467ca7c601647d.jpg
# 1200246_P-ID_R1_31_12_2024_page_5_2048_0_rot180_png.rf.6c7aa73d5a2b5d7ca35740c852a6de36.jpg
# 1200246_P-ID_R1_31_12_2024_page_5_2048_2048_png.rf.d229fbda12097c2f991d0895fc621ffd.jpg
# 1200246_P-ID_R1_31_12_2024_page_5_2048_2048_rot180_png.rf.5c75b5a595356fb3858b60c2ab8c068b.jpg
# 1200246_P-ID_R1_31_12_2024_page_5_3072_2048_png.rf.982f5bd74c125ae024b1c25196feeed5.jpg
# 1200246_P-ID_R1_31_12_2024_page_5_3072_2048_rot180_png.rf.a12745599acca5f2956e5ccc9c906960.jpg
# 152-W-27th-St_21SW-Addendum-1-HVAC-Set_page_2_grid_1x1_jpg.rf.8da544a0336a1d4410698aef99e9d68f.jpg
# 152-W-27th-St_21SW-Addendum-1-HVAC-Set_page_2_grid_1x2_jpg.rf.95e328c4faee24da04474e9caa8664e1.jpg
# 152-W-27th-St_21SW-Addendum-1-HVAC-Set_page_2_grid_1x3_jpg.rf.185cade19db2246634a8179f23b4acb7.jpg
# 152-W-27th-St_21SW-Addendum-1-HVAC-Set_page_2_grid_2x2_jpg.rf.e89ef4b1c5843292f7b89fd5f8d7c2a5.jpg
# 152-W-27th-St_21SW-Addendum-1-HVAC-Set_page_2_grid_3x2_jpg.rf.5776979accbbaccf5577305edb5dac92.jpg
# 1-ROCK-5FL-HVAC-Set-Addendum-1_1_page_3_grid_1x1_jpg.rf.d91d0fa5c76950906feea3931dc93c17.jpg
# 1-ROCK-5FL-HVAC-Set-Addendum-1_1_page_3_grid_1x2_jpg.rf.813cbf53d5e14ef9d8e9b6949a48fe59.jpg
# 1-ROCK-5FL-HVAC-Set-Addendum-1_1_page_3_grid_2x1_jpg.rf.b939a5cd9cbeded037f1acc79e1ddb50.jpg
# 1-ROCK-5FL-HVAC-Set-Addendum-1_1_page_3_grid_2x2_jpg.rf.91295a9b53c6f2855042bbea505b3cc5.jpg
# 1-ROCK-5FL-HVAC-Set-Addendum-1_1_page_3_grid_2x3_jpg.rf.6d6ed7b5c716438aac346a0f1f9d7710.jpg
# 1-ROCK-5FL-HVAC-Set-Addendum-1_1_page_3_grid_3x1_jpg.rf.030d9842c03f21cf51dc5db258504847.jpg
# 1-ROCK-5FL-HVAC-Set-Addendum-1_1_page_3_grid_3x2_jpg.rf.159d15b04b039621379e8a3de7da31e3.jpg
# 1ROCK-STUDIO_ALL-TRADES_BidSet_2024030_page_51_grid_1x1_jpg.rf.5bdbf38a4594ee26293ef68b5bff8b19.jpg
# 1ROCK-STUDIO_ALL-TRADES_BidSet_2024030_page_51_grid_2x1_jpg.rf.4762b4518584b4a41f96b30f855d6285.jpg
# 1ROCK-STUDIO_ALL-TRADES_BidSet_2024030_page_51_grid_2x2_jpg.rf.f5adb7958fbca17f2dde2ae97ccc23be.jpg
# 1ROCK-STUDIO_ALL-TRADES_BidSet_2024030_page_51_grid_3x1_jpg.rf.cc56eb571111cf3c1948da85f892bbe6.jpg
# 1ROCK-STUDIO_ALL-TRADES_BidSet_2024030_page_51_grid_3x2_jpg.rf.0dbb1e4de4c40f0c63e7724c13d83010.jpg
# 1ROCK-STUDIO_ALL-TRADES_BidSet_2024030_page_51_grid_3x3_jpg.rf.65dc5074aa1ce508351689b84bfaa37c.jpg
# 200-Kent-Wonder-HVAC-Set_1_page_3_grid_1x1_jpg.rf.3dcec7ad21c9a448ff07774f1619e0d2.jpg
# 200-Kent-Wonder-HVAC-Set_1_page_3_grid_1x2_jpg.rf.e69ad1f082bae1247c19be5d9929a304.jpg
# 200-Kent-Wonder-HVAC-Set_1_page_3_grid_2x1_jpg.rf.8ca8922ef10e046a1039a0beaad8f73e.jpg
# 200-Kent-Wonder-HVAC-Set_1_page_3_grid_2x3_jpg.rf.a84f191b3bd44a9bbaa38c18f587089d.jpg
# 200-Madison-10th-Floor-HVAC-Set_1_page_4_grid_1x1_jpg.rf.0c7c1b1595911ab77078c842a78bc909.jpg
# 200-Madison-10th-Floor-HVAC-Set_1_page_4_grid_1x2_jpg.rf.47acac711c77423f1d84ce63856a6d85.jpg
# 200-Madison-10th-Floor-HVAC-Set_1_page_4_grid_1x3_jpg.rf.49ec66f3cb9167fac97b21cb4904bcf1.jpg
# 200-Madison-10th-Floor-HVAC-Set_1_page_4_grid_2x1_jpg.rf.19253557d7d12e0720a1f92b827732fe.jpg
# 200-Madison-10th-Floor-HVAC-Set_1_page_4_grid_2x2_jpg.rf.8344446a4897cc5c1854cd0ce414f5a2.jpg
# 200-Madison-10th-Floor-HVAC-Set_1_page_4_grid_3x3_jpg.rf.770b1fc9099efb6f3e1892a4341886c2.jpg
# 200-Madison-10th-Floor-HVAC-Set-ARRAY_1_page_4_grid_1x1_jpg.rf.af7e331708ab2d1fd498850e9fc297ad.jpg
# 200-Madison-10th-Floor-HVAC-Set-ARRAY_1_page_4_grid_1x2_jpg.rf.b260dfef56a9ad310a9eef06a2202108.jpg
# 200-Madison-10th-Floor-HVAC-Set-ARRAY_1_page_4_grid_1x3_jpg.rf.d67c4ecbe61a2506eb3ebb58d3735ead.jpg
# 200-Madison-10th-Floor-HVAC-Set-ARRAY_1_page_4_grid_2x1_jpg.rf.d62954ea40dfcdc2c47a10c2926f18ce.jpg
# 200-Madison-10th-Floor-HVAC-Set-ARRAY_1_page_4_grid_2x2_jpg.rf.7d36c6f733e83480ce1aa80c55ae8548.jpg
# 200-Madison-10th-Floor-HVAC-Set-ARRAY_1_page_4_grid_2x3_jpg.rf.c663d5a95deacedd138f1d6205edd3a4.jpg
# 200-Madison-10th-Floor-HVAC-Set-Pre-Build_1_page_4_grid_2x1_jpg.rf.58b655da20e1a2f0383e89c9dacf1656.jpg
# 200-Madison-10th-Floor-HVAC-Set-Pre-Build_1_page_4_grid_2x2_jpg.rf.771045dce15924f3ca9356227eae5611.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_1_page_19_grid_1x1_jpg.rf.05b05207a512a29e32e490f8ccebfb11.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_1_page_19_grid_1x2_jpg.rf.5fc361911d16cc0d94263036c8bbcfde.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_1_page_19_grid_1x3_jpg.rf.bab64a61420cf4147f85d8177bac27c2.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_1_page_19_grid_2x1_jpg.rf.cd50472600538072d771a23acc76af46.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_1_page_19_grid_2x2_jpg.rf.758d00326b06b485a21b73c4293af008.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_1_page_19_grid_2x3_jpg.rf.3c92d3ee749df3b4cae182f73e127cc5.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_1_page_19_grid_3x1_jpg.rf.6c0ee8b0e2b691c2a7b280895795f0c4.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_1_page_19_grid_3x2_jpg.rf.64ee9a459664b1c332a88c6e1580d928.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_1_page_19_grid_3x3_jpg.rf.415833ec2c2b8aa47d59eac876ad028d.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_14_grid_1x1_jpg.rf.b09fbcc48e5ae5a33cafe8269ada8d3a.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_14_grid_1x2_jpg.rf.99c774907ef705c81aaad77cb34560fc.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_14_grid_2x1_jpg.rf.195d235b0b248df22577a6498e6cdb44.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_14_grid_2x2_jpg.rf.323a63660386c2ecdbb8a4f06725503c.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_14_grid_2x3_jpg.rf.d26bb89c06faf3c38b6d03555f43bd7c.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_8_grid_1x1_jpg.rf.1211d2bb5e05780d0aae4edcf4da62a3.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_8_grid_1x2_jpg.rf.6237b91fbfaa4656b77b0071dd2229e3.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_8_grid_2x1_jpg.rf.a5daacdf9e5dec9930632bb0dc411531.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_8_grid_2x3_jpg.rf.11e7438181503ea8f06f1bdf1a655f30.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_8_grid_3x1_jpg.rf.e1185819e8a370c8e6c5f9ffed2b3a6f.jpg
# 2023_03_29_285-CPW-10S_Building-Submittal-Drawings_page_8_grid_3x3_jpg.rf.fcc52c0ff12447bed0f76e805b5829a0.jpg
# 2023_05_05_285-CPW-10S_Building-Submission_Drawings_1_page_15_grid_1x1_jpg.rf.34abdf52d2ea11ba5b88240d3c265a43.jpg
# 2023_05_05_285-CPW-10S_Building-Submission_Drawings_1_page_15_grid_1x2_jpg.rf.adaa892f41985f9ec645cb757f05859e.jpg
# 2023_05_05_285-CPW-10S_Building-Submission_Drawings_1_page_15_grid_2x1_jpg.rf.d75ef4f684d856de4dca15317fa3c3ee.jpg
# 2023_05_05_285-CPW-10S_Building-Submission_Drawings_1_page_15_grid_2x2_jpg.rf.787d3453316525245b88c6ab9cdacd19.jpg
# 2023-06-21_515-Park-12_100_-DD-MEP-Set_page_8_grid_1x1_jpg.rf.51957457a24cd12808699d50b2e74ce3.jpg
# 2023-06-21_515-Park-12_100_-DD-MEP-Set_page_8_grid_1x2_jpg.rf.512159b443c8a0816359f8e95f8f29e0.jpg
# 2023-06-21_515-Park-12_100_-DD-MEP-Set_page_8_grid_1x3_jpg.rf.0a2395fb7d73dad8b762f40de611e29c.jpg
# 2023-06-21_515-Park-12_100_-DD-MEP-Set_page_8_grid_2x2_jpg.rf.def2f322c03199ebef4acf948784d8df.jpg
# 2023-06-21_515-Park-12_100_-DD-MEP-Set_page_8_grid_2x3_jpg.rf.6cedb070f5a1fdeed22d7d952dc7368f.jpg
# 2023-06-21_515-Park-12_100_-DD-MEP-Set_page_8_grid_3x1_jpg.rf.a2274c2080d70437e88393fa76ccc3c4.jpg
# 2023-06-21_515-Park-12_100_-DD-MEP-Set_page_8_grid_3x2_jpg.rf.eaae5f20047ca346a5b2fcb31c8e2313.jpg
# 2023-06-21_515-Park-12_100_-DD-MEP-Set_page_8_grid_3x3_jpg.rf.0cc52817b5345dabfd8d410be32b0855.jpg
# ...
# _annotations.coco.json
# BDV-2_png.rf.b154ea32d0d7d8718f0a22f788ec441b.jpg
# COCA_page_2_2048_1024_rot180_png.rf.97072e900c0c047ee6423c9a11479dd4.jpg
# COCA_page_2_2048_2048_rot180_png.rf.39aac6559267ed693cd6ad3854cc1ffa.jpg
# COCA_page_2_3072_0_rot180_png.rf.caadabcabefa7b5454770595b959d650.jpg
# COCA_page_3_0_1024_rot180_png.rf.c3ff18840210e982f45dc54e70e629bd.jpg
# COCA_page_3_0_2048_png.rf.398e65f691e6ac30a939e628c95b143e.jpg
# COCA_page_3_2048_1024_png.rf.b7ac1f6e69ab9faf50ea799cbe1fbea0.jpg
# COCA_page_5_1024_1024_png.rf.3b5dedc70526a485a994a82d00d3bf02.jpg
# COCA_page_5_2048_1024_png.rf.d5739e51f354c3615314627a9e0f3861.jpg
# COCA_page_5_4096_1024_png.rf.d091997c364fe9b11268769f4da33374.jpg
# data11_png.rf.6d17ab3e8813e102a9abc1958107468e.jpg
# data14_png.rf.a9ca33e153b56f7d5def83376e65ded5.jpg
# data15_png.rf.8f5c8485f554bc1c81cad336c69a388c.jpg
# data26_png.rf.b3cd15d1c441655cc1240ca15b009fbc.jpg
# data4_png.rf.39e1ea6c63f42a3690b11c7f3cad1578.jpg
# ERCP_10_r1_c2_png.rf.263921c1e4435d0bd944e0090e38642f.jpg
# ERCP_10_r1_c3_png.rf.f5133699666921d75848f4aa4c7eddf2.jpg
# ERCP_10_r2_c1_png.rf.f3b51fc484f57c0c4cf721c6601dc596.jpg
# ERCP_10_r2_c2_png.rf.1f52bc9d960452cf92b98abf5413c73d.jpg
# ERCP_10_r2_c3_png.rf.705976fa5cede91f1c97828ea61d78c9.jpg
# ERCP_11_r0_c2_png.rf.97812f0ef21102b2a05452e41807274c.jpg
# ERCP_11_r0_c4_png.rf.bb93816924d123523524bf3c8da3772c.jpg
# ERCP_11_r1_c2_png.rf.7b5d53f5cc057f8f433deb73533578a1.jpg
# ERCP_11_r1_c4_png.rf.afbd56b2b377d3d9d5902bbac2fa8abe.jpg
# ERCP_12_r0_c1_png.rf.456192ed2a606cc569eae8550655b646.jpg
# ERCP_12_r1_c2_png.rf.28a1bbcb0235621bb2c99127a433aa4f.jpg
# ERCP_12_r2_c0_png.rf.ce3b18baf78909d8d74181bbd915b77c.jpg
# ERCP_12_r2_c2_png.rf.90b347b7a3c53bc7ebbf10c278853816.jpg
# ERCP_12_r3_c0_png.rf.296a3960132edeb92fd0308c41f4ba20.jpg
# ERCP_13_r1_c3_png.rf.4f6528ac9eb9f7619562f09039a72408.jpg
# ERCP_14_r0_c3_png.rf.ee0538d90eb109a8f50d2fc4a9f4f242.jpg
# ERCP_14_r1_c4_png.rf.c2a2157c8f1b93b3e412c3bfdebc32e2.jpg
# ERCP_14_r2_c2_png.rf.b917aad41ba75e4ad96683dedff06304.jpg
# ERCP_14_r2_c3_png.rf.789f92e26e84c3e27f01754efca2fdd8.jpg
# ERCP_15_r1_c3_png.rf.03be668705b4669cf76872b5e2457f92.jpg
# ERCP_15_r2_c4_png.rf.435834d66568468a7b16a22049aa7b42.jpg
# ERCP_15_r3_c3_png.rf.1f6e7b7c9a85fb88fd88bf934fb982d4.jpg
# ERCP_16_r0_c3_png.rf.a0ad0541c930ee8d9f9de68234518bea.jpg
# ERCP_16_r1_c0_png.rf.4245a9e4ba914de5e35afd8a44194396.jpg
# ERCP_16_r1_c1_png.rf.2777becb8f63fa2519fa4cd0fec253cc.jpg
# ERCP_16_r1_c1_png.rf.ab5f2da2db47f4a6716ebe0636f60089.jpg
# ERCP_16_r1_c4_png.rf.a5fca77bab4b604887388626f8feedab.jpg
# ERCP_17_r2_c0_png.rf.7ef326345a608d9bbca71c782e7d9291.jpg
# ERCP_17_r2_c4_png.rf.90d71d3dfdbf0b38b6fc8fc21c8d931f.jpg
# ERCP_18_r2_c1_png.rf.3a992016acfa905436b144552c1613c2.jpg
# ERCP_18_r2_c2_png.rf.6c2ca77530eeb5c4b141755bf40182e4.jpg
# ERCP_18_r2_c4_png.rf.fda2c2aaea537a355337b7d84a48dd71.jpg
# ERCP_20_r2_c3_png.rf.e4c69d0672d85f459d871cf2e1ae92c4.jpg
# ERCP_21_r1_c0_png.rf.d05402ed0cb94c17d318faf56bc6f82e.jpg
# ERCP_21_r1_c1_png.rf.7b32ff98e524b2acf89fdd96bb5e6439.jpg
# ERCP_21_r2_c2_png.rf.1692d98ca37b56d4c72d1138942c45e9.jpg
# ERCP_21_r2_c3_png.rf.b3eedcc0d187a415b1a485e7fd9dcaf2.jpg
# ERCP_23_r0_c5_png.rf.efdf725a4f3afb41c3151f2a034bda03.jpg
# ERCP_24_r3_c1_png.rf.83e2c87375ce249e1f383d82b29318c3.jpg
# ERCP_24_r3_c3_png.rf.f64526b74f007950d8304bcfcc41640b.jpg
# ERCP_25_r1_c1_png.rf.c0f3a97d22c54c2b2ce86757b53f0ece.jpg
# ERCP_25_r1_c2_png.rf.453f7576bc353de865cc4deddb11159a.jpg
# ERCP_26_r0_c2_png.rf.e83125c7a1e5b772dfc1895ec9d823d5.jpg
# ERCP_26_r1_c1_png.rf.d0661e933faa3bc1d7795cabb2253a2b.jpg
# ERCP_26_r1_c2_png.rf.16c57efbaaa52f26f6024760df3ce6f2.jpg
# ERCP_26_r3_c3_png.rf.0c6afb7bd39c99609e339245cbf15a40.jpg
# ERCP_29_r1_c3_png.rf.6d1b66e77e1912ad599c92eb446e9e7b.jpg
# ERCP_2_r1_c1_png.rf.88ab80476b422e5319c319da3007063f.jpg
# ERCP_2_r1_c4_png.rf.8bc8eb0728ff8ea05d55bdf8bf97c13b.jpg
# ERCP_2_r2_c3_png.rf.6b4fedd0daff451926006d2251217e44.jpg
# ERCP_31_r0_c1_png.rf.4888517dbe2c231f4c59026b596942f4.jpg
# ERCP_31_r1_c1_png.rf.8b4465faf20bb03563b75dc34abb92e2.jpg
# ERCP_31_r2_c3_png.rf.01f12279e0399ebe158b2839abffa856.jpg
# ERCP_31_r2_c3_png.rf.f855fb25228b860e71728727182de6fa.jpg
# ERCP_32_r3_c2_png.rf.41dc8247f05a6c42557450ffa2988c8b.jpg
# ERCP_36_r1_c4_png.rf.f6b194d3858b5f4a98b82bae34d815a8.jpg
# ERCP_38_r2_c5_png.rf.99f88b88c8ac39bab95382e3fd91ab16.jpg
# ERCP_39_r1_c1_png.rf.f4e3aefa195c237ca1f029a45cf871eb.jpg
# ERCP_40_r2_c4_png.rf.29009ef12c2f268c549aee0c330aabad.jpg
# ERCP_44_r2_c3_png.rf.7e77ae46008145fe76b1d623d0bd5a29.jpg
# ERCP_44_r3_c1_png.rf.78512c9d32077c284c8ee5eb7501fd36.jpg
# ERCP_45_r1_c2_png.rf.1c7344fbda3601a62ef82462cd0a9bac.jpg
# ERCP_4_r2_c3_png.rf.8cb9792d8bbfe844919f7925e32da9a0.jpg
# ERCP_4_r3_c0_png.rf.36fa2018373397ad04af34eb6637edcb.jpg
# ERCP_5_r2_c2_png.rf.fe22f8c5125828f6e8197c4e4e677a70.jpg
# ERCP_62_r0_c0_png.rf.56914cff587673f35e16cafba6195e48.jpg
# ERCP_7_r1_c1_png.rf.8008a0162bf95951504ce5575685b0a9.jpg
# ERCP_7_r1_c4_png.rf.47a2ebdc2dde0834a8c61b7a966ae321.jpg
# ERCP_7_r2_c1_png.rf.7533dcea4d15c1409c29982aa843b8ba.jpg
# ERCP_8_r0_c0_png.rf.98d9b0801e9297efd2599e4e24a7af63.jpg
# ERCP_8_r0_c1_png.rf.fd2c2b55293310c0e7054485196e9661.jpg
# ERCP_8_r1_c0_png.rf.457a9a21fe8323212dc148c274e99ee1.jpg
# ERCP_9_r1_c3_png.rf.c1ce79a19e9188079df0aad249d128ce.jpg
# ERCPP_13_r0_c0_png.rf.516857071815fca622812ac81a9210d1.jpg
# ERCPP_14_r1_c1_png.rf.c42a6a28c8ece50142ad966a70ad49e6.jpg
# ERCPP_16_r0_c0_png.rf.16207662d51f11a7b169e77958ce3be2.jpg
# ERCPP_2_r0_c2_png.rf.430f99c8c9deb4c16e8e03690056497a.jpg
# ERCPP_37_r1_c1_png.rf.72948b11a72d3639470fe21c0a65972a.jpg
# ERWA_7_r0_c1_png.rf.d2bc287cb3344c00e9f1e93c021b1ffe.jpg
# FCV-3_png.rf.d1da0ef13033fc27a208d0227d93b45f.jpg
# FCV-5_png.rf.1533bf8dba041afc7c7b18aeb58e3816.jpg
# Funan_34_r0_c0_png.rf.9d5bbe4d2b34337e4e5e059482b72315.jpg
# Funan_36_r0_c1_png.rf.2a8ac20841195661c9b86a2860aaae3f.jpg
# Funan_38_r1_c1_png.rf.0805c2f9688c2fceddf44b7c69162c9d.jpg
# Funan_43_r0_c1_png.rf.997cdc05fc2d64cb2279394fcb1ce489.jpg
# Funan_45_r0_c0_png.rf.57e96f8d90c20a7343acfb483e93601d.jpg
# Funan_51_r0_c0_png.rf.ef02f9b119839da1b338d7a42645b392.jpg
# Funan_51_r1_c0_png.rf.3caf79ddae8c88387941d681190df573.jpg
# Funan_7_r0_c0_png.rf.5e36a2dcbec158e5efa522c0b1c06d07.jpg
# HVAC-Set-11_16_2023_Apple-Bank_Queens-Blvd_Bid-Set_page_4_grid_16_jpg.rf.e25e963d2f59a903e75756cdd00c1232.jpg
# HVAC-Set-11_16_2023_Apple-Bank_Queens-Blvd_Bid-Set_page_4_grid_6_jpg.rf.0ce2596388230db06ff02863569dd507.jpg
# HVAC-Set-24-0501_Wonder_Midtown_90-Set_Combined_page_2_grid_14_jpg.rf.b2431df2b0b652c1512ab1e4dee3feec.jpg
# HVAC-Set-24-0501_Wonder_Midtown_90-Set_Combined_page_2_grid_17_jpg.rf.0d6365767d7e3109c03a739f908f0175.jpg
# HVAC-Set-24-0501_Wonder_Midtown_90-Set_Combined_page_2_grid_20_jpg.rf.06c016f98e78b843bdfd27e627ba389b.jpg
# HVAC-Set-24-0501_Wonder_Midtown_90-Set_Combined_page_2_grid_25_jpg.rf.461d913a2b6704033862986155b18e3d.jpg
# Kith-Permit-Mechanical-6-14-2024_page_6_grid_16_jpg.rf.d66ac04b8212c365ea527503b5d07715.jpg
# Kith-Permit-Mechanical-6-14-2024_page_6_grid_19_jpg.rf.b59e502a5965e539da50be91d6b925ee.jpg
# LCV-1_png.rf.5fc861c31e0c8bed8e6adf5bf26d1351.jpg
# LCV-1_png.rf.626fa368583ab1c01b22ab0cc400dca8.jpg
# LCV-1_png.rf.d23a7b20608df10105458cce6ad0cb6c.jpg
# louvers-and-dampers-marked-HVAC-Set-1001-6th-Ave-11th-Issued-For-Pricing_page_3_grid_18_jpg.rf.08274834f01c470dd142950a9ae16918.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_11_grid_15_jpg.rf.e40461199f2bc1a2913aceaa24ae9154.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_11_grid_16_jpg.rf.1c6d3bfa40dce05da10fe90783dfcf5d.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_11_grid_18_jpg.rf.cf07f92e3eaf837db1a827bce2b726b7.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_11_grid_2_jpg.rf.730179552035156a2ab0f355278438c6.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_9_grid_12_jpg.rf.0ca9e695ac514ab467618549d97585b4.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_9_grid_17_jpg.rf.1cf32df44ed623fbc267da4e4567ea35.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_9_grid_19_jpg.rf.00069f7a624df2eca773c69da8ba3a61.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_9_grid_7_jpg.rf.2b57b7f5101a7881bcdd56e6a171b643.jpg
# Mechanical-B32835-ApdAddInfoPlans-031524_page_9_grid_8_jpg.rf.e23eec8a826656388e2c602572b2c8c6.jpg
# Mechanical-HVAC_1_page_10_grid_13_jpg.rf.f35b253f0686e5bab992a15ea173d885.jpg
# Mechanical-HVAC_1_page_10_grid_14_jpg.rf.169f7b607fa5e2b5c0e2ad9ddb37c459.jpg
# Mechanical-HVAC_1_page_10_grid_17_jpg.rf.84c72bbcc7003d1be4d6b9b839869615.jpg
# Mechanical-HVAC_1_page_9_grid_2_jpg.rf.eb6c603c4677a54f3f7ed78ce1a2d193.jpg
# MEP_Bulletin_-3_4th_Floor-DD_100-_page_4_grid_11_jpg.rf.311cc839ce231ad32780e717632c29e0.jpg
# MEP_Bulletin_-3_4th_Floor-DD_100-_page_4_grid_17_jpg.rf.f5a12581b3ff6117f0839f79e5b2b8e0.jpg
# MEP_Bulletin_-3_4th_Floor-DD_100-_page_4_grid_23_jpg.rf.5c1b00836d41b42c6c50f4073a2dcc78.jpg
# MEP-s-10239_2023-10-05_Progress-Set_page_30_grid_12_jpg.rf.9828c6de7d28ac803f3fac56f3703e51.jpg
# MEP-s-10239_2023-10-05_Progress-Set_page_30_grid_22_jpg.rf.f1761ed2e016e74da9637572425a1929.jpg
# newdata10_png.rf.9846f1fe2eb2419d74ce16b5fa0c242f.jpg
# newdata50_png.rf.3353082a338a4755e3e271dda29e79cb.jpg
# newdata56_png.rf.1f91a78d22ebc108cb7946159b709031.jpg
# patch_12_resized_640x640_png.rf.cf28725c038b93cdd39709ead3777af6.jpg
# PCV-2_png.rf.ed39901d142d1f1c00715aa46c4d567a.jpg
# PCV-6_png.rf.0aa67b5213ec7037fb8de91f2feea703.jpg
# Phenix-Salon-Riverdale-MEPS_1_page_3_grid_11_jpg.rf.08adbf6b805b5538b122ba8950693a81.jpg
# pid_00001_jpg_33_jpg.rf.e5dd002959e1ad62b8f599ac8b8432c2.jpg
# pid_00001_jpg_56_jpg.rf.d2e591c53c5871184ee071b0f2c38b1b.jpg
# pid_00003_jpg_28_jpg.rf.e7e69fda60c05eaf5689778a7fde5c33.jpg
# pid_00004_jpg_61_jpg.rf.dac89bb28a0da559ced183eef9b26cc8.jpg
# pid_00005_jpg_33_jpg.rf.fa12f5c78f01ec870616dea53e539f35.jpg
# pid_00006_jpg_23_jpg.rf.e556483568c517562903fdbd741b5e99.jpg
# pid_00006_jpg_38_jpg.rf.407ad9dc562be2bbd622f7aa5301a0d7.jpg
# pid_00006_jpg_97_jpg.rf.a8f568da27e21f22207af169c41515f4.jpg
# pid_00007_jpg_61_jpg.rf.85addbaf7a913e74d05a895d33b53198.jpg
# pid_00007_jpg_67_jpg.rf.be26642dfa5f4b14f543749191ee737a.jpg
# pid_00007_jpg_88_jpg.rf.ddde418d76694b3975da67620af90ba6.jpg
# pid_00007_jpg_95_jpg.rf.fe7c5c6a8fee1c3972ed3c7cd16085fd.jpg
# pid_00010_jpg_65_jpg.rf.3080aa392e7bd4ed81e3d3da9b0182ad.jpg
# pid_00010_jpg_66_jpg.rf.1422c51fadc824995955f56b8784f022.jpg
# pid_00011_jpg_24_jpg.rf.e3c24721e95d3c37911f4aa1f737dcf6.jpg
# pid_00011_jpg_40_jpg.rf.601db1a5106f2bfbc03626c28ae08ee8.jpg
# pid_00011_jpg_91_jpg.rf.6c3b2c814c8dfadf8049df578ecf474c.jpg
# pid_00014_jpg_25_jpg.rf.b026b582ff446a2c7fa5470746f13bf4.jpg
# pid_00014_jpg_53_jpg.rf.c8f25a47617b33403d604f57c6758170.jpg
# pid_00016_jpg_20_jpg.rf.95472f6726eb1cbdfdb22964438e9d8b.jpg
# pid_00018_jpg_37_jpg.rf.f76dba6fec126bef4a2356fcf3486c4f.jpg
# pid_00018_jpg_4_jpg.rf.f8c478d05b5a7ea1471908d0f74f1ffd.jpg
# pid_00019_jpg_52_jpg.rf.ee1b86b371a1cb2dfca293980c8cbb35.jpg
# pid_00021_jpg_33_jpg.rf.8bc3ed1843479bcdd5c1e0d706f6f5aa.jpg
# pid_00021_jpg_43_jpg.rf.1b0ef974f5ad1aba63a641b0bde5ba05.jpg
# pid_00021_jpg_70_jpg.rf.e5679107cd1448e004f42d75883c18fb.jpg
# pid_00021_jpg_83_jpg.rf.efc232aaa5d04a14642394df260cbd22.jpg
# pid_00021_jpg_92_jpg.rf.975b9e65d969e398531cb18d2732a41e.jpg
# pid_00022_jpg_60_jpg.rf.f38b51571fe9f77050b48bed0e3fa1d6.jpg
# pid_00024_jpg_37_jpg.rf.77c9f3375f78864aab05dc8a5a71f54c.jpg
# Platong_1_11_r0_c2_png.rf.3d5898f64ac4215c9776f7335c8ae011.jpg
# Platong_1_12_r1_c0_png.rf.78cd158a9eee3f3404b9a5bd80ce502c.jpg
# Platong_1_23_r0_c1_png.rf.1c4a47ef809852dcc90d2abe8cf6545b.jpg
# Platong_1_35_r0_c0_png.rf.718cb247ebc7deae2ae610ff8fc495d1.jpg
# Platong_1_50_r1_c1_png.rf.f703b95b680eaaeca5723b8366f4a4cd.jpg
# Platong_2_2_r0_c2_png.rf.62598a5bf5160f75553add8b3178ec9e.jpg
# Platong_2_2_r1_c1_png.rf.901b6493575577ecfd9c7067095a32dc.jpg
# Platong_3_41_r1_c1_png.rf.dc3e2f2abd7ac94ef6e5b74176ef3b00.jpg
# Platong_3_41_r1_c1_png.rf.fa43dfc8c01605cf01db837d65c1e616.jpg
# Platong_3_45_r1_c0_png.rf.66d5df7c6cda18deb5ebf0bfbe36a15e.jpg
# Platong_3_46_r0_c1_png.rf.b28871101f04f4a9bb50911a386162b8.jpg
# preview22_png.rf.20691b60ec7785aa121646b892e9dc08.jpg
# preview2_png.rf.6a810bd183cd7b5a748f45e02e184b06.jpg
# preview41_png.rf.ecc39f3aeb4a5c12aebe9e9a8142ad4f.jpg
# preview43_png.rf.eeb5df1eabdce956c782bd25317339f2.jpg
# preview4_png.rf.fd2b6bfa188d155c9a5151abc3b2e541.jpg
# preview50_png.rf.b8ac97cb35f20df83f002061c63780e4.jpg
# preview9_png.rf.ed96f25fcc56c3326557fd139a890703.jpg
# Reznor-Ducted-Heater-Submittal-SE-Review_page_11_grid_7_jpg.rf.9b88f34a7945c97672f89fcf0ed225b5.jpg
# Sample_a_1_patch_1_png_jpg.rf.390fec70d8f1eeab740caff1cd328a6a.jpg
# Sample_a_1_patch_5_png_jpg.rf.4fe219fef7b155dc80bf6cfe6fab1570.jpg
# Sample_a_2_patch_3_png_jpg.rf.19262d27362a9b3db1ca3880c1a07fb0.jpg
# Sample_a_5_patch_0_png_jpg.rf.3b98b272b40fe6540d92769f2bce64a0.jpg
# Sample_a_5_patch_7_png_jpg.rf.95413c0139d5e2d76131fc12fe84ca4e.jpg
# Sample_b_1_patch_4_png_jpg.rf.c973fee688bb87629e5157f4813ab13b.jpg
# Sample_b_2_patch_4_png_jpg.rf.45c0ee97e4c8d925e02ad9b4c6268cd7.jpg
# Sample_b_2_patch_5_png_jpg.rf.d1b4d9dc056cc67b0d92bb0df70af452.jpg
# Sample_b_4_patch_7_png_jpg.rf.1a8a1edebb2feb04768fdce4c577292a.jpg
# Sample_b_5_patch_7_png_jpg.rf.9e80981d630ec3884ee4e8085978b05e.jpg
# Sample_c_2_patch_5_png_jpg.rf.f4a2cf055ca31a7aed4587ae28eabc1a.jpg
# Sample_c_2_patch_7_png_jpg.rf.5841ca7df318b944a2f28f49d6d2b219.jpg
# Sample_c_3_patch_6_png_jpg.rf.cba4109c6d92311a5a43ddab97da2b4e.jpg
# Sample_c_5_patch_1_png_jpg.rf.f5691e5d9f6dd84e86b98dc7e10542ec.jpg
# Sample_c_5_patch_2_png_jpg.rf.466327d77cd37c71147a39e6c6a75ee6.jpg
# Sample_c_5_patch_6_png_jpg.rf.e35a5467330833e4bcd00c20b3168866.jpg
# Sample_d_1_patch_1_png_jpg.rf.f82a365876d2945e10e8a882b9cb1a8a.jpg
# Sample_d_2_patch_2_png_jpg.rf.8abaa0b3ba685f94517e7245f7ef8060.jpg
# Sample_d_3_patch_4_png_jpg.rf.8fbe2671df0acdd403a7246e909db79a.jpg
# Sample_d_3_patch_8_png_jpg.rf.74f2b65fb5ae525df2a11f0eb833cf07.jpg
# Sample_d_4_patch_1_png_jpg.rf.252aa81b5acf0017ad6cc27cf2d20465.jpg
# Sample_d_4_patch_6_png_jpg.rf.e7a34b4488625b7bfeaec18d1c6edc7e.jpg
# Screenshot-2024-06-05-114531_png.rf.761da586eb6497c783bcc436cdc24d43.jpg
# Screenshot-2025-08-06-071446_png.rf.383851788dad2a6d5be9562207cdc650.jpg
# Screenshot-2025-08-06-071516_png.rf.8740ccc262947c2cdf3ab0dd96537588.jpg
# Screenshot-2025-08-06-073726_png.rf.0e73fd48099a5e982faba04dfbde2fcb.jpg
# Screenshot-from-2022-10-04-10-23-55_png.rf.f9b20ee6be771907bd1c85b716f53963.jpg
# Screenshot-from-2022-10-04-10-25-27_png.rf.dead6de868868430bc73bcb49821a7a8.jpg
# Screenshot-from-2022-10-04-10-26-24_png.rf.c9dd205a93e2911cd1744c84847d355c.jpg
# Screenshot-from-2022-10-04-10-28-52_png.rf.dfa8c8b6d8f44385d99304c762eef17a.jpg
# Screenshot-from-2022-10-04-10-29-49_png.rf.688466983fd3f8325fc9aa0f3b3106b8.jpg
# Screenshot-from-2022-10-04-10-30-41_png.rf.fa1d40592bc94e7584dbcfd29cfde80b.jpg
# Screenshot-from-2022-10-04-10-31-15_png.rf.c2b27c449a9ff6df62c05397a6d05e9c.jpg
# Screenshot-from-2022-10-04-10-31-24_png.rf.ec557e9e6cbd408343938bab6753ee71.jpg
# Screenshot-from-2022-10-04-10-33-12_png.rf.d8b9b2b270b67a1e766590b0b1df91f5.jpg
# Screenshot-from-2022-10-04-10-34-20_png.rf.13401d0b681f46cd2162a446e4d295a6.jpg
# T00106018_mechanical_bid-filing_20240402-HVAC-Set_1_page_7_grid_13_jpg.rf.79a8b51655c5cf47386d86226a040778.jpg
# T00106018_mechanical_bid-filing_20240402-HVAC-Set_1_page_7_grid_16_jpg.rf.abd1242cb9c0a439df3d43767cd00da9.jpg
# T00106018_mechanical_bid-filing_20240402-HVAC-Set_1_page_7_grid_6_jpg.rf.d641dcf9f23331e2d7f557183d9a3329.jpg
# TISHMAN-1-ROCK-5FL-ARCH-MEPS-IFB_021524_2_page_37_grid_3_jpg.rf.072db476f383e47f5909bd06407eb9ae.jpg
# TRI-EC-BEA-PR-12-53-4035-1-3-A_jpeg.rf.5a0b95f15ce1a044ab5aa790a75a164a.jpg
# TRI-EC-BEA-PR-12-53-4038-1-3_jpeg.rf.42d76caf680ba03b591fb09afcb51fcf.jpg
# TRI-EC-BEA-PR-12-53-4038-3-3-A_jpeg.rf.2d24d45ce01182b166f7db953979a5f6.jpg
# TRI-EC-BEA-PR-12-53-4045-A_jpeg.rf.9f9c29110f593c6fa960e0a980a20a8a.jpg
# TRI-EC-BEA-PR-12-53-4051-A_jpeg.rf.36a3c18f024a47f0a9f392848eedd8eb.jpg
# TRI-EC-BEA-PR-12-53-4057_jpeg.rf.6e64f482316be6ca6d38b28a65b60521.jpg
# TSP-666-3rd-Ave-14th-Floor-Terrace-and-Prebuild-Addendum-1-Arch-3_4_24_1_page_14_grid_16_jpg.rf.72db70a79283b75daa1617f70fef3943.jpg
# Warby-Parker-New-York-NY-Bid-Set-12-6-24_page_37_grid_1_jpg.rf.a495fb8a91adf97f9aa8b7d649bded42.jpg

# %%
import os
import urllib.request

# Define URL for the official ViT-H model
CHECKPOINT_URL = "https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth"
CHECKPOINT_PATH = "/content/sam_vit_h_4b8939.pth"

print(f"⬇️ Downloading official SAM ViT-H weights to {CHECKPOINT_PATH}...")
if not os.path.exists(CHECKPOINT_PATH):
    urllib.request.urlretrieve(CHECKPOINT_URL, CHECKPOINT_PATH)
    print("✅ Download complete.")
else:
    print("✅ File already exists.")
# Out:
# ⬇️ Downloading official SAM ViT-H weights to /content/sam_vit_h_4b8939.pth...
# ✅ Download complete.

# %% [markdown]
# ### Phase 4: Model Preparation and Training Setup

# %%
# Initialize model and optimizer first to allow for state loading
sam_model = sam_model_registry[CONFIG['model_type']]()
sam_model.to(CONFIG['device'])
optimizer = torch.optim.Adam(sam_model.mask_decoder.parameters(), lr=CONFIG['learning_rate'], weight_decay=CONFIG['weight_decay'])

start_epoch = 0

# --- NEW: RESUME TRAINING LOGIC ---
if CONFIG['resume_training']:
    print(f"🔄 Attempting to resume training from {CONFIG['latest_checkpoint_save_path']}")
    if os.path.exists(CONFIG['latest_checkpoint_save_path']):
        checkpoint = torch.load(CONFIG['latest_checkpoint_save_path'])
        sam_model.load_state_dict(checkpoint['model_state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        start_epoch = checkpoint['epoch'] + 1
        print(f"✅ Resumed successfully. Starting from epoch {start_epoch}.")
    else:
        print("⚠️ Resume checkpoint not found. Starting training from scratch with pre-trained SAM.")
        # Load the base pre-trained model if resume fails
        sam_model.load_state_dict(torch.load(CONFIG['model_path']))
else:
    print(f"🔄 Starting new training session from pre-trained model: {CONFIG['model_path']}")
    sam_model.load_state_dict(torch.load(CONFIG['model_path']))

# Configure model for fine-tuning (freeze encoders)
sam_model.train()
for name, param in sam_model.named_parameters():
    if name.startswith("image_encoder") or name.startswith("prompt_encoder"):
        param.requires_grad = False

trainable_params = sum(p.numel() for p in sam_model.parameters() if p.requires_grad)
print(f"✅ SAM model configured for fine-tuning. Trainable parameters: {trainable_params:,}")
# Out:
# 🔄 Starting new training session from pre-trained model: /content/sam_vit_h_4b8939.pth
# ✅ SAM model configured for fine-tuning. Trainable parameters: 4,058,340

# %%
import torch
import torch.nn as nn

# Setup scheduler and loss function
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

def combined_loss(pred_masks: torch.Tensor, true_masks: torch.Tensor) -> torch.Tensor:
    bce_loss = nn.BCEWithLogitsLoss()(pred_masks, true_masks.float())
    pred_flat = torch.sigmoid(pred_masks).reshape(-1)
    true_flat = true_masks.reshape(-1)
    intersection = (pred_flat * true_flat).sum()
    dice_loss = 1 - (2. * intersection + 1e-8) / (pred_flat.sum() + true_flat.sum() + 1e-8)
    return 0.8 * bce_loss + 0.2 * dice_loss

print("✅ Scheduler and loss function configured.")
# Out:
# ✅ Scheduler and loss function configured.

# %% [markdown]
# ### Phase 5: Training and Validation Loop

# %%
### Phase 5: Training and Validation Loop (Optimized for T4 GPU)

def run_epoch(model, dataloader, optimizer, is_training, device, epoch):
    model.train(is_training)
    epoch_losses, iou_scores = [], []

    desc = "Training" if is_training else "Validation"
    for batch_idx, batch in enumerate(tqdm(dataloader, desc=desc)):
        images = batch['image'].to(device, non_blocking=True)
        all_gt_masks_list = batch['masks']
        all_prompts_list = batch['prompts']

        # For training, we must clear gradients at the start of each image (batch)
        if is_training:
            optimizer.zero_grad()

        with torch.set_grad_enabled(is_training):
            with torch.no_grad():
                image_embeddings = model.image_encoder(images)

            total_loss_for_image = 0
            num_annotations_in_image = 0

            # This loop structure is correct for batch_size = 1
            if len(all_gt_masks_list) > 0:
                # Loop through every annotation for the current image
                for j in range(len(all_gt_masks_list[0])):
                    gt_mask_np = all_gt_masks_list[0][j]
                    prompt = all_prompts_list[0][j]
                    num_annotations_in_image += 1

                    gt_mask_torch = torch.from_numpy(gt_mask_np).unsqueeze(0).unsqueeze(0).to(device)
                    transform = ResizeLongestSide(CONFIG['image_size'])

                    box_torch, points_torch, points_label_torch = None, None, None
                    if 'box' in prompt:
                        box_torch = torch.as_tensor(transform.apply_boxes(prompt['box'].reshape(1, 4), batch['original_size'][0]), dtype=torch.float, device=device)
                    elif 'point_coords' in prompt:
                        points_torch = torch.as_tensor(transform.apply_coords(prompt['point_coords'], batch['original_size'][0]), dtype=torch.float, device=device).unsqueeze(0)
                        points_label_torch = torch.as_tensor(prompt['point_labels'], dtype=torch.float, device=device).unsqueeze(0)

                    with torch.no_grad():
                        sparse_embeddings, dense_embeddings = model.prompt_encoder(
                            points=(points_torch, points_label_torch) if points_torch is not None else None,
                            boxes=box_torch,
                            masks=None
                        )

                    low_res_masks, iou_predictions = model.mask_decoder(
                        image_embeddings=image_embeddings,
                        image_pe=model.prompt_encoder.get_dense_pe(),
                        sparse_prompt_embeddings=sparse_embeddings,
                        dense_prompt_embeddings=dense_embeddings,
                        multimask_output=False,
                    )

                    upscaled_masks = model.postprocess_masks(low_res_masks, batch['input_size'][0], batch['original_size'][0])

                    # Calculate loss for this single annotation
                    loss = combined_loss(upscaled_masks, gt_mask_torch)

                    # --- TRUE GRADIENT ACCUMULATION STEP ---
                    if is_training:
                        # Normalize the loss by the number of annotations to keep gradients stable
                        normalized_loss = loss / len(all_gt_masks_list[0])
                        # Calculate and accumulate gradients for this single, tiny loss
                        normalized_loss.backward()

                    total_loss_for_image += loss.item()

                    if not is_training:
                        pred_mask = (torch.sigmoid(upscaled_masks) > 0.5).squeeze().cpu().numpy().astype(np.uint8)
                        iou = mask_utils.iou([mask_utils.encode(np.asfortranarray(pred_mask))], [mask_utils.encode(np.asfortranarray(gt_mask_np.astype(np.uint8)))], [0])[0][0]
                        iou_scores.append(iou)

            # --- OPTIMIZER STEP AFTER ALL ANNOTATIONS ---
            # After processing all annotations for the image, update the model weights ONCE
            if is_training and num_annotations_in_image > 0:
                optimizer.step()
                # The gradients are automatically cleared by the zero_grad() at the start of the next batch

            if num_annotations_in_image > 0:
                epoch_losses.append(total_loss_for_image / num_annotations_in_image)

        # Checkpoint saving logic
        if is_training and (batch_idx + 1) % CONFIG['checkpoint_batch_interval'] == 0:
            chk_path = CONFIG['latest_checkpoint_save_path']
            torch.save({'epoch': epoch, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()}, chk_path)
            tqdm.write(f"\n💾 Overwrote latest checkpoint (for crash recovery): {os.path.basename(chk_path)}")

    return {'loss': mean(epoch_losses) if epoch_losses else 0, 'iou': mean(iou_scores) if iou_scores else 0}


# --- Main Training Loop ---
best_val_iou = 0
patience_counter = 0
history = {'train_loss': [], 'val_loss': [], 'val_iou': []}

print(f"\n🚀 Starting training from epoch {start_epoch} for {CONFIG['num_epochs']} total epochs...")
for epoch in range(start_epoch, CONFIG['num_epochs']):
    print(f"\n--- Epoch {epoch+1}/{CONFIG['num_epochs']} ---")

    train_metrics = run_epoch(sam_model, train_loader, optimizer, is_training=True, device=CONFIG['device'], epoch=epoch)
    history['train_loss'].append(train_metrics['loss'])

    val_metrics = run_epoch(sam_model, val_loader, None, is_training=False, device=CONFIG['device'], epoch=epoch)
    history['val_loss'].append(val_metrics['loss'])
    history['val_iou'].append(val_metrics['iou'])

    print(f"Train Loss: {train_metrics['loss']:.4f}")
    print(f"Val Loss: {val_metrics['loss']:.4f} | Val IoU: {val_metrics['iou']:.4f}")

    scheduler.step(val_metrics['loss'])

    if val_metrics['iou'] > best_val_iou:
        best_val_iou = val_metrics['iou']
        patience_counter = 0
        best_model_path = CONFIG['best_model_save_path']
        torch.save(sam_model.state_dict(), best_model_path)
        print(f"🏆 New best model saved with IoU: {best_val_iou:.4f}")
    else:
        patience_counter += 1

    if patience_counter >= CONFIG['early_stopping_patience']:
        print(f"🛑 Early stopping triggered after {patience_counter} epochs with no improvement.")
        break

print("\n✅ Training completed!")
# Out:
# 🚀 Starting training from epoch 0 for 1 total epochs...
#
# --- Epoch 1/1 ---
# Training:  11%|█         | 300/2802 [17:59<4:05:40,  5.89s/it]
# 💾 Overwrote latest checkpoint (for crash recovery): latest_checkpoint_multiprompt_v1.pth
# Training:  14%|█▍        | 391/2802 [23:50<1:32:37,  2.31s/it]

# %% [markdown]
# ### Phase 6: Results and Export

# %%
# Plot training metrics
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

ax1.plot(history['train_loss'], label='Training Loss', color='blue')
ax1.plot(history['val_loss'], label='Validation Loss', color='red')
ax1.set_title('Training and Validation Loss')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Loss')
ax1.legend()
ax1.grid(True)

ax2.plot(history['val_iou'], label='Validation IoU', color='green')
ax2.set_title('Validation Metrics (IoU)')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Score')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.savefig(os.path.join(CONFIG['output_dir'], 'training_metrics.png'))
plt.show()

print(f"\n📊 FINAL METRICS:")
if history['val_iou']:
    print(f"Best Validation IoU: {max(history['val_iou']):.4f}")
else:
    print("No validation metrics recorded.")

# %%
# Save the final trained model (or the best one)
final_model_path = os.path.join(CONFIG['output_dir'], 'final_model.pth')
torch.save(sam_model.state_dict(), final_model_path)
print(f"✅ Final model state saved to: {final_model_path}")
print(f"✅ Best performing model (by IoU) saved to: {CONFIG['best_model_save_path']}")

# %%
### Phase 7: Final, Unbiased Evaluation on the Test Set

print("\n--- Final Model Evaluation on Unseen Test Data ---")

# 1. Load the best performing model that was saved during training
best_model_path = CONFIG['best_model_save_path']
if os.path.exists(best_model_path):
    print(f"🔄 Loading best model from: {best_model_path}")
    # We need to re-initialize the model structure before loading the state dict
    eval_model = sam_model_registry[CONFIG['model_type']]()
    eval_model.load_state_dict(torch.load(best_model_path))
    eval_model.to(CONFIG['device'])
else:
    print("❌ Best model file not found. Cannot perform final evaluation.")
    # You might want to handle this case, but for now we'll assume it exists

# 2. Load the test dataset
try:
    test_coco, test_path = load_coco_split(CONFIG['unzip_path'], 'test', CONFIG['annotations_file_name'])
    test_ids = test_coco.getImgIds()

    # Use is_training=False to ensure validation uses perfect boxes
    test_dataset = HvacSamDataset(test_coco, test_ids, test_path, is_training=False)
    test_loader = DataLoader(test_dataset, batch_size=CONFIG['batch_size'], shuffle=False,
                             num_workers=CONFIG['num_workers'], collate_fn=custom_collate_fn)

    print(f"\n✅ Test dataset loaded with {len(test_dataset)} samples.")

except FileNotFoundError as e:
    print(f"\n⚠️ Test split not found: {e}. Skipping final evaluation.")

# 3. Run a single evaluation pass on the test data
if 'test_loader' in locals() and 'eval_model' in locals():
    print("\n🚀 Running final evaluation on the test set...")
    final_test_metrics = run_epoch(eval_model, test_loader, optimizer=None, is_training=False, device=CONFIG['device'], epoch=0)

    print("\n" + "="*50)
    print("      🎉 FINAL UNBIASED PERFORMANCE METRICS 🎉")
    print("="*50)
    print(f"Final Test IoU:   {final_test_metrics['iou']:.4f}")
    print(f"Final Test Loss:  {final_test_metrics['loss']:.4f}")
    print("="*50)
    print("\nThis is the true expected performance of your model on new data.")
